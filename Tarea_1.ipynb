# %% [markdown]
# # Tarea 1 Bases de Datos 2024-1 Grupo 06_

# %% [markdown]
# ## Integrantes:
# * Mauricio Ramos - 202273041-2
# * Natalia Antileo - 202173070-2
# * Abner Vidal - 202273032-3

# %% [markdown]
# ## Requisitos para Correr el Notebook
#
# Para poder utilizar este Notebook se debe tener instalado:
# - **Python 3**
# - **Jupyter**
# - La librería **ipython-sql** (Poder ejecutar sql en Jupyter Notebook)
# - PostgreSQL y su conector desde Python(**psycopg2**)
#
# **IMPORTANTE:** Este Jupyter Notebook se conectará a su servicio de Base de Datos PostgreSQL de manera **local**, por lo que **no funcionará correctamente en el entorno Google Collab.**
#
# Para instalar las dependencias, ejecute (**recuerde actualizar pip3**):

# %%
! pip3 install ipython-sql

! pip3 install psycopg2
# Out:
# Requirement already satisfied: ipython-sql in c:\users\natal\appdata\local\programs\python\python310\lib\site-packages (0.5.0)
# Requirement already satisfied: prettytable in c:\users\natal\appdata\local\programs\python\python310\lib\site-packages (from ipython-sql) (3.10.0)
# Requirement already satisfied: ipython in c:\users\natal\appdata\local\programs\python\python310\lib\site-packages (from ipython-sql) (8.23.0)
# Requirement already satisfied: sqlalchemy>=2.0 in c:\users\natal\appdata\local\programs\python\python310\lib\site-packages (from ipython-sql) (2.0.29)
# Requirement already satisfied: sqlparse in c:\users\natal\appdata\local\programs\python\python310\lib\site-packages (from ipython-sql) (0.4.3)
# Requirement already satisfied: six in c:\users\natal\appdata\local\programs\python\python310\lib\site-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: ipython-genutils in c:\users\natal\appdata\local\programs\python\python310\lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\natal\appdata\local\programs\python\python310\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (4.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\natal\appdata\local\programs\python\python310\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (3.0.3)
# Requirement already satisfied: decorator in c:\users\natal\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\natal\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\natal\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\natal\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\natal\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (2.17.2)
# Requirement already satisfied: stack-data in c:\users\natal\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\natal\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (5.14.2)
# Requirement already satisfied: exceptiongroup in c:\users\natal\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (1.2.0)
# Requirement already satisfied: colorama in c:\users\natal\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (0.4.5)
# Requirement already satisfied: wcwidth in c:\users\natal\appdata\local\programs\python\python310\lib\site-packages (from prettytable->ipython-sql) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\natal\appdata\local\programs\python\python310\lib\site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.4)
# Requirement already satisfied: executing>=1.2.0 in c:\users\natal\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython->ipython-sql) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\natal\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython->ipython-sql) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\natal\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython->ipython-sql) (0.2.2)
# Requirement already satisfied: psycopg2 in c:\users\natal\appdata\local\programs\python\python310\lib\site-packages (2.9.5)

# %% [markdown]
# ## Importar dependencias

# %%
import random
from datetime import datetime, timedelta

#Librerías para PostgreSQL
import psycopg2

# %% [markdown]
# Para conectarse a la base de datos, completen los datos relevantes en la variable DATABASE_URL.
#
# * Cambie `Grupo6` por el usuario que utilizó en Postgres para acceder a la Base de Datos. Por defecto `postgres`.
# * Cambie `1234` por la contraseña de dicho usuario. **Recuerde borrarla antes de entregar su tarea.**
# * Cambie `5433` por el puerto en que se ejecuta su servicio de Base de Datos. Por defecto `5433`.
# * Cambie `tareabd1` por el nombre de la BD (Schema) que creó en Postgres.
#
# Ejemplo: `postgresql://Grupo6:1234@localhost:5433/tareabd1`

# %%
# %reload_ext sql
# %env DATABASE_URL=postgresql://Grupo6:1234@localhost:5433/tareabd1
# Out:
# env: DATABASE_URL=postgresql://Grupo6:1234@localhost:5433/tareabd1

# %% [markdown]
# Para conectarse de forma declarativa a la Base de Datos, utilice el siguiente código:

# %%
#Recuerde cambiar los valores de USER, DBNAME y PASSWORD por los mismos de la celda superior.
conn = psycopg2.connect(
   host="localhost",
   user="Grupo6",
   dbname='tareabd1',
   password="1234",
   port = 5433
)

print(conn)
# Out:
# <connection object at 0x00000211C388A8A0; dsn: 'user=Grupo6 password=xxx dbname=tareabd1 host=localhost port=5433', closed: 0>

# %% [markdown]
# ## Crear tablas
#
# Aquí inserta el código SQL que creara las tablas de la base de datos:

# %% [markdown]
# ### Tabla "Director"

# %%
# %%sql
# CREATE TABLE director (
#     id_director INTEGER GENERATED ALWAYS AS IDENTITY,
#     nombre VARCHAR(45) NOT NULL,
#     edad INTEGER,
#     PRIMARY KEY(id_director)
# );
# Out:
# Done.
# []

# %% [markdown]
# ### Tabla "Actor"

# %%
# %%sql
# CREATE TABLE actor(
#     id_actor INTEGER GENERATED ALWAYS AS IDENTITY,
#     nombre VARCHAR(45) NOT NULL,
#     edad INTEGER,
#     PRIMARY KEY(id_actor)
# );
# Out:
#  * postgresql://Grupo6:***@localhost:5433/tareabd1
# Done.
# []

# %% [markdown]
# ### Tabla "Pelicula"

# %%
# %%sql
# CREATE TABLE pelicula (
#     id_pelicula INTEGER GENERATED ALWAYS AS IDENTITY,
#     id_director INTEGER NOT NULL,
#     nombre VARCHAR(45) NOT NULL,
#     genero VARCHAR(45) NOT NULL,
#     duracion INTEGER NOT NULL,
#     fecha_publicacion DATE NOT NULL,
#     PRIMARY KEY(id_pelicula),
#     FOREIGN KEY (id_director) REFERENCES director (id_director)
# );
# Out:
#  * postgresql://Grupo6:***@localhost:5433/tareabd1
# Done.
# []

# %% [markdown]
# ### Tabla "actor_participa_en_pelicula"

# %%
# %%sql
# CREATE TABLE actor_participa_en_pelicula (
#     id_actor INTEGER NOT NULL,
#     id_pelicula INTEGER NOT NULL,
#     PRIMARY KEY(id_actor,id_pelicula),
#     FOREIGN KEY (id_actor) REFERENCES actor (id_actor),
#     FOREIGN KEY (id_pelicula) REFERENCES pelicula (id_pelicula)
# );
# Out:
#  * postgresql://Grupo6:***@localhost:5433/tareabd1
# Done.
# []

# %% [markdown]
# ### Tabla  "Premio_mejor_director"

# %%
# %%sql
# CREATE TABLE premio_mejor_director(
#     id_premio INTEGER GENERATED ALWAYS AS IDENTITY,
#     id_director INTEGER NOT NULL,
#     anio INTEGER,
#     PRIMARY KEY(id_premio),
#     FOREIGN KEY (id_director) REFERENCES director (id_director)
# );
# Out:
#  * postgresql://Grupo6:***@localhost:5433/tareabd1
# Done.
# []

# %% [markdown]
# ### Tabla  "Premio_mejor_actor"

# %%
# %%sql
# CREATE TABLE premio_mejor_actor(
#     id_premio INTEGER GENERATED ALWAYS AS IDENTITY,
#     id_actor INTEGER NOT NULL,
#     anio INTEGER,
#     PRIMARY KEY(id_premio),
#     FOREIGN KEY (id_actor) REFERENCES actor (id_actor)
# );
# Out:
#  * postgresql://Grupo6:***@localhost:5433/tareabd1
# Done.
# []

# %% [markdown]
# ### Tabla  "Premio_mejor_pelicula"

# %%
# %%sql
# CREATE TABLE premio_mejor_pelicula(
#     id_premio INTEGER GENERATED ALWAYS AS IDENTITY,
#     id_pelicula INTEGER NOT NULL,
#     anio INTEGER,
#     PRIMARY KEY(id_premio),
#     FOREIGN KEY (id_pelicula) REFERENCES pelicula (id_pelicula)
# );
# Out:
#  * postgresql://Grupo6:***@localhost:5433/tareabd1
# Done.
# []

# %% [markdown]
# ## Código Generador de Datos
#
# Ejecute este código para cargar datos a las tablas creadas.

# %%
import random
from datetime import date
#Prefijos y sufijos para crear nombres de peliculas aleatoriamente
prefijos = ["El misterio de", "El viaje de", "Las aventuras de", "La historia de", "El secreto de", "La leyenda de", "La búsqueda de", "El regreso de", "El tesoro de", "La odisea de", "La misión de", "La conquista de", "La travesía de", "El destino de", "El despertar de", "El último viaje de", "La venganza de", "El renacimiento de", "La rebelión de", "El vuelo de", "El descubrimiento de", "La sombra de", "La redención de", "El ritual de", "La batalla de", "El hechizo de", "El pacto de", "La profecía de", "El laberinto de", "El prisionero de", "La llegada de", "El amanecer de", "La fortuna de", "El enigma de", "La invasión de", "El resurgimiento de", "La metamorfosis de", "El eclipse de", "La danza de", "La canción de", "El lamento de", "La trampa de", "La travesura de", "El tesoro escondido de", "El vuelo mágico de", "El canto de sirena de", "El bosque encantado de", "La maldición de", "La leyenda perdida de", "La tormenta de", "El camino hacia", "El viajero de", "El guardián de", "La cripta de", "El espejismo de", "El secreto oscuro de", "La resurrección de", "La danza macabra de", "La fuga de", "La estrella fugaz de", "El grito de", "El castillo de", "La travesía sin retorno de", "La estirpe de", "La llave de", "El cuento de hadas de", "El príncipe de", "La doncella de", "El arco iris de", "La fuente de", "El refugio de", "La senda de", "La búsqueda del tesoro de", "El caballero de", "La escalada de", "La maldición del vampiro de", "La travesía del océano de"]
sufijos = ["el león", "la bailarina", "el sapo", "la estrella", "el mago", "la princesa", "el guerrero", "la criatura", "el explorador", "la bruja", "la montaña", "la isla", "el dragón", "la cueva", "el lobo", "la reina", "el rey", "la espada", "el castillo", "la flor", "la selva", "el tesoro", "la nube", "el unicornio", "la sirena", "el volcán", "la neblina", "la cascada", "el árbol", "la ciudad", "el río", "la tormenta", "la luna", "el sol", "la estrella fugaz", "el camino", "la sombra", "el laberinto", "la ola", "la caverna", "el mar", "el ángel", "la espada mágica", "el destino", "el faro", "el puente", "el horizonte", "el valle", "el puente", "la muralla", "el bosque", "la gruta", "la corona", "la aldea", "la batalla", "la noche", "el amanecer", "el atardecer", "el sueño", "la pesadilla", "el héroe", "la heroína", "la aventura", "el misterio", "la magia", "la leyenda", "la profecía", "el secreto", "el desafío", "la trampa", "la mariposa", "el jardín", "la tormenta", "la montaña", "el río", "el rincón", "el guardián", "el hechizo", "la misión", "la expedición", "la caza", "el trono", "la batalla", "la aventura", "el legado", "el enigma", "la clave", "el guardián", "el viajero", "la cripta", "el laberinto", "el abismo", "el muro", "la senda", "el laberinto", "la bruma", "la travesía", "el vuelo", "la sirena", "el hechicero", "la escuela", "la academia", "la sombra", "la estrella", "el ángel", "la gárgola", "la profecía", "la puerta", "la guerra", "el pacto", "la ley", "el viaje", "la huida", "la fortuna", "la prisión", "la cárcel", "el lamento", "la sonrisa", "el susurro", "el grito", "la fuga", "el monstruo", "la bestia", "la maraña", "el sueño", "la pesadilla", "la verdad", "el mito", "el océano", "la estrella", "el fuego", "la tierra", "el cielo", "la oscuridad", "la luz", "el caos", "la esperanza", "la promesa", "la traición", "el destino", "la salvación", "la perdición", "la soledad", "la compañía", "la amistad", "el amor", "la pasión", "la venganza", "el perdón", "el renacer", "el adiós", "la bienvenida", "la despedida", "el encuentro", "la desgracia", "la fortuna", "la guerra", "la paz", "la caída", "el renacimiento", "la resistencia", "el sacrificio", "la alianza", "el viaje", "el descubrimiento", "la revelación", "la esperanza", "la batalla", "el peligro", "la aventura", "la magia", "la pesadilla", "el misterio", "la leyenda", "la guerra", "el amor", "la traición", "la redención", "la libertad", "la prisión", "la oscuridad", "la luz", "la corrupción"]
#Nombres y apellidos para crear nombres de peliculas aleatoriamente
nombres = ["Akira", "Alessandro", "Chen", "Darius", "Emiko", "Fatemeh", "Gustavo", "Hiroko", "Isa", "Jin", "Katarina", "Lakshmi", "Mikhail", "Nina", "Omar", "Pilar", "Qiu", "Rashid", "Sakura", "Tatiana", "Umar", "Valentina", "Wang", "Xavier", "Yasmin", "Zafar", "Aarav", "Beatriz", "Chidike", "Darya", "Elif", "Fadhila", "Giovanni", "Hanako", "Ilya", "Jasmin", "Khaled", "Leticia", "Mehmet", "Nadia", "Orhan", "Parvati", "Quintus", "Rania", "Salim", "Theresa", "Ursula", "Vivek", "Wilhelmina", "Xin", "Yusef", "Zoya", "Abdullah", "Bianca", "Chiyoko", "Dmitri", "Elena", "Fabiana", "Genghis", "Han", "Irina", "Javier", "Kamala", "Leonardo", "Mina", "Natalia", "Oscar", "Patricia", "Quentin", "Rosa", "Samir", "Tatjana", "Umberto", "Valeria", "Wan", "Ximena", "Yuri", "Zara"]
apellidos = ["Abadi", "Bianchi", "Cruz", "Dutta", "Etxebarria", "Ferreira", "Gao", "Hernandez", "Ivanov", "Janssen", "Kawaguchi", "Lopez", "Montenegro", "Nguyen", "Olivares", "Petrov", "Qian", "Rodriguez", "Santos", "Tan", "Ueno", "Vargas", "Wu", "Xia", "Yilmaz", "Zhang", "Almeida", "Borges", "Carvalho", "Diniz", "Esteves", "Fernandes", "Gomes", "Henriquez", "Inácio", "Joaquim", "Lima", "Mendes", "Nogueira", "Oliveira", "Pereira", "Quintana", "Ramos", "Santana", "Teixeira", "Uchoa", "Vieira", "Xavier", "Yamamoto", "Zambrano", "Alvarez", "Barros", "Correia", "Duarte", "Estevez", "Figueiredo", "Goncalves", "Hidalgo", "Iglesias", "Jimenez", "Kumar", "Lopes", "Martinez", "Nunes", "Ortega", "Pacheco", "Queiroz", "Rocha", "Sousa", "Teles", "Urbina", "Velez", "Watanabe", "Xu", "Yan", "Zapata"]
# Definir el rango de fechas
fecha_inicial = datetime(1960, 1, 1)
fecha_final = datetime(2023, 12, 31)

# Calcular la diferencia entre las fechas inicial y final
diferencia = fecha_final - fecha_inicial

# Generar una fecha aleatoria dentro del rango
fecha_aleatoria = fecha_inicial + timedelta(days=random.randint(0, diferencia.days))

# Convertir la fecha al formato SQL DATE (YYYY-MM-DD)
fecha_sql = fecha_aleatoria.strftime('%Y-%m-%d')

cursor = conn.cursor()

premios_info = {}
directores_ids = []
for _ in range(200):
    nombre = random.choice(nombres) + " " + random.choice(apellidos)
    edad = random.randint(30,90)
    cursor.execute("INSERT INTO director (nombre, edad) VALUES (%s, %s) RETURNING id_director", (nombre, edad))
    id_director = cursor.fetchone()[0]
    directores_ids.append(id_director)
    
actores_ids = []
for _ in range(200):
    nombre = random.choice(nombres) + " " + random.choice(apellidos)
    edad = random.randint(15,70) 
    cursor.execute("INSERT INTO actor (nombre, edad) VALUES (%s, %s) RETURNING id_actor", (nombre, edad))
    id_actor = cursor.fetchone()[0]
    actores_ids.append(id_actor)

peliculas_ids = []
for _ in range(300):
    director_pelicula = random.choice(directores_ids)
    nombre = random.choice(prefijos) + " " + random.choice(sufijos)
    genero = random.choice(["Acción", "Aventura", "Animación", "Comedia", "Documental", "Drama", "Fantasía", "Terror", "Ciencia ficción", "Musical", "Misterio", "Romance", "Suspense", "Western"])
    duracion = random.randint(70,150)
    fecha_aleatoria = fecha_inicial + timedelta(days=random.randint(0, diferencia.days))
    # Convertir la fecha al formato SQL DATE (YYYY-MM-DD)
    fecha_sql = fecha_aleatoria.strftime('%Y-%m-%d')
    cursor.execute("INSERT INTO pelicula (id_director, nombre, genero, duracion, fecha_publicacion) VALUES (%s,%s,%s,%s,%s) RETURNING id_pelicula",(director_pelicula,nombre,genero,duracion,fecha_sql))
    id_pelicula = cursor.fetchone()[0]
    peliculas_ids.append(id_pelicula)
    if id_pelicula not in premios_info:
        premios_info[id_pelicula] = {}
        premios_info[id_pelicula]["año"] = fecha_aleatoria.year
        premios_info[id_pelicula]["director"] = director_pelicula
        premios_info[id_pelicula]["genero"] = genero
        premios_info[id_pelicula]["cast"] = []
        premios_info[id_pelicula]["mejor pelicula"] = "no"
    
lista_pelicula_actor = []
peliculas_actores = {}
for _ in range(500):
    peliculaID = random.choice(peliculas_ids)
    actorID = random.choice(actores_ids)
    if not (peliculaID, actorID) in lista_pelicula_actor:
        cursor.execute("INSERT INTO actor_participa_en_pelicula (id_pelicula, id_actor) VALUES (%s,%s)",(peliculaID,actorID))
        lista_pelicula_actor.append((peliculaID,actorID))
    else:
        continue


for pelicula, actor in lista_pelicula_actor:
    if pelicula in premios_info:
        premios_info[pelicula]["cast"].append(actor)

print(premios_info)
for _ in range(100):
    pelicula_al_azar = random.randint(1,300)
    tipo_de_premio = ["mejor pelicula", "mejor actor", "mejor director"]
    eleccion_premio = random.choice(tipo_de_premio)
    if eleccion_premio == "mejor director":
        if premios_info[pelicula_al_azar]["director"] != "elegido":
            director = premios_info[pelicula_al_azar]["director"]
            año = premios_info[pelicula_al_azar]["año"]
            cursor.execute("INSERT INTO premio_mejor_director (id_director, anio) VALUES (%s,%s)",(director, año))
            premios_info[pelicula_al_azar]["director"] = "elegido"
        else:
            continue
    elif eleccion_premio == "mejor actor":
        if premios_info[pelicula_al_azar]["cast"] != []:
            actor = random.choice(premios_info[pelicula_al_azar]["cast"])
            año = premios_info[pelicula_al_azar]["año"]
            cursor.execute("INSERT INTO premio_mejor_actor (id_actor, anio) VALUES (%s,%s)",(actor, año))
            premios_info[pelicula_al_azar]["cast"].remove(actor)
        else:
            continue
    elif eleccion_premio == "mejor pelicula":
        if premios_info[pelicula_al_azar]["mejor pelicula"] != "si":
            pelicula = pelicula_al_azar
            año = premios_info[pelicula_al_azar]["año"]
            cursor.execute("INSERT INTO premio_mejor_pelicula (id_pelicula, anio) VALUES (%s,%s)",(pelicula, año))
            premios_info[pelicula_al_azar]["mejor pelicula"] = "si"
        else:
            continue

conn.commit()
cursor.close()
conn.close()
# Out:
# {1: {'año': 1986, 'director': 102, 'genero': 'Romance', 'cast': [148, 116], 'mejor pelicula': 'no'}, 2: {'año': 2016, 'director': 112, 'genero': 'Aventura', 'cast': [93, 65], 'mejor pelicula': 'no'}, 3: {'año': 1988, 'director': 174, 'genero': 'Suspense', 'cast': [], 'mejor pelicula': 'no'}, 4: {'año': 2000, 'director': 144, 'genero': 'Misterio', 'cast': [65], 'mejor pelicula': 'no'}, 5: {'año': 1973, 'director': 112, 'genero': 'Documental', 'cast': [], 'mejor pelicula': 'no'}, 6: {'año': 1979, 'director': 47, 'genero': 'Drama', 'cast': [176, 57, 170], 'mejor pelicula': 'no'}, 7: {'año': 2015, 'director': 99, 'genero': 'Romance', 'cast': [74, 90], 'mejor pelicula': 'no'}, 8: {'año': 1987, 'director': 175, 'genero': 'Fantasía', 'cast': [], 'mejor pelicula': 'no'}, 9: {'año': 1970, 'director': 63, 'genero': 'Romance', 'cast': [93, 166], 'mejor pelicula': 'no'}, 10: {'año': 1997, 'director': 4, 'genero': 'Documental', 'cast': [93, 180], 'mejor pelicula': 'no'}, 11: {'año': 1998, 'director': 88, 'genero': 'Documental', 'cast': [], 'mejor pelicula': 'no'}, 12: {'año': 1969, 'director': 161, 'genero': 'Acción', 'cast': [198, 167], 'mejor pelicula': 'no'}, 13: {'año': 1960, 'director': 80, 'genero': 'Misterio', 'cast': [127], 'mejor pelicula': 'no'}, 14: {'año': 2021, 'director': 122, 'genero': 'Terror', 'cast': [119, 19], 'mejor pelicula': 'no'}, 15: {'año': 1970, 'director': 111, 'genero': 'Terror', 'cast': [194, 69], 'mejor pelicula': 'no'}, 16: {'año': 1998, 'director': 161, 'genero': 'Terror', 'cast': [130, 72], 'mejor pelicula': 'no'}, 17: {'año': 1960, 'director': 32, 'genero': 'Drama', 'cast': [], 'mejor pelicula': 'no'}, 18: {'año': 1967, 'director': 199, 'genero': 'Fantasía', 'cast': [196, 135, 198], 'mejor pelicula': 'no'}, 19: {'año': 1963, 'director': 116, 'genero': 'Misterio', 'cast': [184, 124], 'mejor pelicula': 'no'}, 20: {'año': 1989, 'director': 129, 'genero': 'Suspense', 'cast': [114, 84], 'mejor pelicula': 'no'}, 21: {'año': 1964, 'director': 152, 'genero': 'Animación', 'cast': [52], 'mejor pelicula': 'no'}, 22: {'año': 1971, 'director': 44, 'genero': 'Aventura', 'cast': [], 'mejor pelicula': 'no'}, 23: {'año': 2022, 'director': 32, 'genero': 'Aventura', 'cast': [184, 26], 'mejor pelicula': 'no'}, 24: {'año': 1970, 'director': 4, 'genero': 'Documental', 'cast': [137, 98, 116, 91, 135], 'mejor pelicula': 'no'}, 25: {'año': 1962, 'director': 158, 'genero': 'Romance', 'cast': [156, 135, 145], 'mejor pelicula': 'no'}, 26: {'año': 1982, 'director': 170, 'genero': 'Musical', 'cast': [107], 'mejor pelicula': 'no'}, 27: {'año': 1963, 'director': 50, 'genero': 'Acción', 'cast': [157, 75], 'mejor pelicula': 'no'}, 28: {'año': 2019, 'director': 169, 'genero': 'Drama', 'cast': [166], 'mejor pelicula': 'no'}, 29: {'año': 1970, 'director': 39, 'genero': 'Ciencia ficción', 'cast': [68, 149], 'mejor pelicula': 'no'}, 30: {'año': 1976, 'director': 172, 'genero': 'Ciencia ficción', 'cast': [171], 'mejor pelicula': 'no'}, 31: {'año': 1996, 'director': 167, 'genero': 'Romance', 'cast': [55, 128, 102], 'mejor pelicula': 'no'}, 32: {'año': 1994, 'director': 111, 'genero': 'Documental', 'cast': [129, 90], 'mejor pelicula': 'no'}, 33: {'año': 1993, 'director': 18, 'genero': 'Musical', 'cast': [179, 8], 'mejor pelicula': 'no'}, 34: {'año': 1971, 'director': 132, 'genero': 'Suspense', 'cast': [], 'mejor pelicula': 'no'}, 35: {'año': 2008, 'director': 160, 'genero': 'Suspense', 'cast': [1], 'mejor pelicula': 'no'}, 36: {'año': 1993, 'director': 190, 'genero': 'Fantasía', 'cast': [52], 'mejor pelicula': 'no'}, 37: {'año': 1971, 'director': 25, 'genero': 'Suspense', 'cast': [], 'mejor pelicula': 'no'}, 38: {'año': 1981, 'director': 25, 'genero': 'Romance', 'cast': [163, 99], 'mejor pelicula': 'no'}, 39: {'año': 1961, 'director': 119, 'genero': 'Terror', 'cast': [191, 144, 121], 'mejor pelicula': 'no'}, 40: {'año': 1983, 'director': 170, 'genero': 'Drama', 'cast': [153, 162], 'mejor pelicula': 'no'}, 41: {'año': 1985, 'director': 77, 'genero' ...

# %% [markdown]
# ## Consultas
#
# Escriba aquí las consultas pedidas. Recuerde agregar una descripción _breve_ de cómo funciona la solución. **Escriba las consultas de forma ordenada.**
#
# **NOTA:** Cuando en una consulta diga "X cosa" significa que ustedes deben de elegir ese X por lo que para cualquier otro X debe de funcionar de igual forma.

# %% [markdown]
# ### Consulta 1
# **Nombre de todas las películas publicadas desde el año pasado.**
#
#
# **Ejemplo:**
# |Nombre|
# |------|
# |Dune 2|
# |...|
#
#
# **Solución:** _Dentro de la tabla película, realizamos una búsqueda de todas las películas con el fecha de publicación que tenga como año 2023, y simplemente consultamos el nombre._

# %%
# %%sql
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */
# SELECT
#     nombre AS "Nombre"
# FROM
#     pelicula
# WHERE
#     EXTRACT(YEAR FROM pelicula.fecha_publicacion) = 2023;
# Out:
# 6 rows affected.
# [('El destino de la desgracia',),
#  ('La estirpe de la batalla',),
#  ('La fortuna de el destino',),
#  ('El secreto de la bienvenida',),
#  ('La batalla de el lamento',),
#  ('El hechizo de la misión',)]

# %% [markdown]
# ### Consulta 2
# **Nombre y fecha de publicación de todas las películas del género drama que hayan sido publicadas en el año 2023.**
#
#
# **Ejemplo:**
#
# |Nombre     |Fecha de publicación|
# |-----------|--------------------|
# |Oppenheimer|21-7-2023          |
# |...        |...                 |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */
# SELECT
#     nombre AS "Nombre", fecha_publicacion AS "Fecha de publicación"
# FROM
#     pelicula
# WHERE
#     genero = 'Drama' AND EXTRACT(YEAR FROM pelicula.fecha_publicacion) = 2023;
# Out:
#  * postgresql://Grupo6:***@localhost:5433/tareabd1
# 0 rows affected.
# []

# %% [markdown]
# ### Consulta 3
# **Nombres de todos los actores que participaron en una película de género comedia.**
#
#
# **Ejemplo:**
# |Nombre       |
# |-------------|
# |Margot Robbie|
# |...          |
#
#
# **Solución:**
# Al hacer INNER JOIN de las tablas actor_participa_en_pelicula y película, con la condición de que película.generi = ‘Comedia’, se se obtiene una tabla “intermedia” renombrada como act_comedia con los ids de todos los actores que participan en películas de este género, luego se utiliza esta tabla nueva junto con la tabla actor para relacionar y obtener los nombres de los actores al aplicar la condición actor.id_actor = act_comedia.id_act

# %%
# %%sql
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */
# SELECT
#     actor.nombre AS "Nombre"
# FROM
#     actor,
#     (SELECT
#         actor_participa_en_pelicula.id_actor AS id_act
#     FROM actor_participa_en_pelicula INNER JOIN pelicula ON actor_participa_en_pelicula.id_pelicula=pelicula.id_pelicula
#     WHERE
#         pelicula.genero = 'Comedia')AS act_comedia
# WHERE
#     actor.id_actor = act_comedia.id_act
#  ;
# Out:
# 32 rows affected.
# [('Wan Pereira',),
#  ('Valentina Ferreira',),
#  ('Umar Hidalgo',),
#  ('Zara Oliveira',),
#  ('Mehmet Lopez',),
#  ('Wan Yilmaz',),
#  ('Lakshmi Lopez',),
#  ('Theresa Velez',),
#  ('Samir Yamamoto',),
#  ('Valeria Almeida',),
#  ('Quentin Quintana',),
#  ('Zara Goncalves',),
#  ('Valeria Gao',),
#  ('Chen Esteves',),
#  ('Salim Kawaguchi',),
#  ('Mina Almeida',),
#  ('Umar Hidalgo',),
#  ('Qiu Carvalho',),
#  ('Wan Martinez',),
#  ('Emiko Carvalho',),
#  ('Darya Zapata',),
#  ('Pilar Dutta',),
#  ('Genghis Zambrano',),
#  ('Bianca Inácio',),
#  ('Valentina Ferreira',),
#  ('Quentin Quintana',),
#  ('Wan Pereira',),
#  ('Hanako Yan',),
#  ('Yuri Estevez',),
#  ('Fabiana Yilmaz',),
#  ('Katarina Etxebarria',),
#  ('Han Nunes',)]

# %% [markdown]
# ### Consulta 4
# **Nombre y cantidad de premios ganados por cada género, ordenados de mayor a menor según la cantidad de premios.**
#
#
# **Ejemplo:**
# |Género  |Cantidad de premios|
# |--------|-------------------|
# |Drama   |99                 |
# |Fantasía|29                 |
# |...     |...                |
#
#
#
# **Solución:** _Primero hacemos un left join de las tablas película y premio_mejor_pelicula, con esta nueva tabla, agrupando por el género, contamos los id_pelicula que coincidan._

# %%
# %%sql
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */
# SELECT
#     pelicula.genero AS "Género",
#     COUNT(premio_mejor_pelicula.id_pelicula) AS "Cantidad de premios"
# FROM
#     pelicula LEFT JOIN premio_mejor_pelicula
#     ON premio_mejor_pelicula.id_pelicula = pelicula.id_pelicula
# GROUP BY
#     pelicula.genero
# ORDER BY
#     "Cantidad de premios" DESC;
# Out:
#  * postgresql://Grupo6:***@localhost:5433/tareabd1
# 14 rows affected.
# [('Suspense', 6),
#  ('Aventura', 5),
#  ('Documental', 5),
#  ('Acción', 3),
#  ('Comedia', 2),
#  ('Musical', 2),
#  ('Terror', 2),
#  ('Romance', 1),
#  ('Drama', 1),
#  ('Animación', 1),
#  ('Misterio', 1),
#  ('Western', 1),
#  ('Ciencia ficción', 0),
#  ('Fantasía', 0)]

# %% [markdown]
# ### Consulta 5
# **Mostrar peliculas que tengan 2 o mas actores/actrices ordenadas de mayor a menor segun la cantidad de actores/actrices.**
#
#
# **Ejemplo:**
# |Nombre     |Cantidad de actores|
# |-----------|-------------------|
# |Oppenheimer|7                  |
# |Poor Things|4                  |
# |...        |...                |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */
# SELECT
#     Nombre AS "Nombre",
#     cnt_actores AS "Cantidad de Actores"
# FROM
#     (
#         SELECT
#             pelicula.nombre AS Nombre, COUNT(*) AS cnt_actores
#         FROM
#             pelicula INNER JOIN actor_participa_en_pelicula ON pelicula.id_pelicula = actor_participa_en_pelicula.id_pelicula
#             INNER JOIN actor ON actor_participa_en_pelicula.id_actor = actor.id_actor
#         GROUP BY
#             pelicula.nombre
#         ORDER BY
#             cnt_actores DESC
#     )
# WHERE
#     cnt_actores > 1;
# Out:
#  * postgresql://Grupo6:***@localhost:5433/tareabd1
# 149 rows affected.
# [('La resurrección de la sombra', 6),
#  ('La estrella fugaz de la ola', 6),
#  ('El refugio de la guerra', 6),
#  ('El castillo de la heroína', 6),
#  ('La travesía sin retorno de el rincón', 5),
#  ('El laberinto de la esperanza', 5),
#  ('La danza de la noche', 5),
#  ('La escalada de el mar', 5),
#  ('La batalla de la montaña', 5),
#  ('El pacto de la aldea', 5),
#  ('El viajero de el laberinto', 5),
#  ('La estirpe de la gárgola', 5),
#  ('El laberinto de la sonrisa', 4),
#  ('El renacimiento de el legado', 4),
#  ('La trampa de la criatura', 4),
#  ('La invasión de la bruma', 4),
#  ('El bosque encantado de el lamento', 4),
#  ('La leyenda de la corrupción', 4),
#  ('El amanecer de la pesadilla', 4),
#  ('El destino de la sirena', 4),
#  ('El caballero de la despedida', 4),
#  ('El ritual de la fortuna', 4),
#  ('El hechizo de el laberinto', 4),
#  ('La trampa de el guardián', 4),
#  ('La metamorfosis de la tormenta', 4),
#  ('El bosque encantado de la leyenda', 4),
#  ('El despertar de la sirena', 4),
#  ('El laberinto de la ola', 4),
#  ('El renacimiento de la travesía', 3),
#  ('La travesura de la bestia', 3),
#  ('La tormenta de el dragón', 3),
#  ('La leyenda perdida de el laberinto', 3),
#  ('La travesía del océano de la estrella', 3),
#  ('El hechizo de la salvación', 3),
#  ('La conquista de la noche', 3),
#  ('La leyenda perdida de la tormenta', 3),
#  ('El lamento de el caos', 3),
#  ('El lamento de la aldea', 3),
#  ('La resurrección de el guardián', 3),
#  ('La maldición del vampiro de la muralla', 3),
#  ('La travesura de la flor', 3),
#  ('El viajero de la maraña', 3),
#  ('La venganza de la estrella fugaz', 3),
#  ('El misterio de el desafío', 3),
#  ('El renacimiento de el hechizo', 3),
#  ('La metamorfosis de el monstruo', 3),
#  ('El arco iris de la gárgola', 3),
#  ('El tesoro escondido de la ley', 3),
#  ('El canto de sirena de el faro', 3),
#  ('La batalla de el vuelo', 3),
#  ('La escalada de el enigma', 3),
#  ('El último viaje de la pesadilla', 3),
#  ('El hechizo de la aventura', 3),
#  ('La llave de el sueño', 3),
#  ('El viaje de la resistencia', 3),
#  ('El refugio de la estrella fugaz', 3),
#  ('El príncipe de la pesadilla', 3),
#  ('El caballero de el adiós', 3),
#  ('El refugio de el río', 3),
#  ('La búsqueda de el fuego', 3),
#  ('La travesía sin retorno de la estrella', 3),
#  ('La travesura de el secreto', 3),
#  ('El pacto de la cripta', 3),
#  ('El amanecer de el misterio', 2),
#  ('La maldición del vampiro de el abismo', 2),
#  ('El guardián de el descubrimiento', 2),
#  ('La historia de el laberinto', 2),
#  ('La tormenta de la senda', 2),
#  ('El caballero de la verdad', 2),
#  ('El prisionero de la venganza', 2),
#  ('La llave de la oscuridad', 2),
#  ('La estrella fugaz de el viaje', 2),
#  ('La leyenda perdida de la maraña', 2),
#  ('El camino hacia el adiós', 2),
#  ('La resurrección de el león', 2),
#  ('El descubrimiento de la princesa', 2),
#  ('La estrella fugaz de la sirena', 2),
#  ('La batalla de el castillo', 2),
#  ('El amanecer de el árbol', 2),
#  ('La búsqueda del tesoro de el pacto', 2),
#  ('El misterio de el hechicero', 2),
#  ('La leyenda de la pesadilla', 2),
#  ('La trampa de la pesadilla', 2),
#  ('La venganza de la esperanza', 2),
#  ('El laberinto de el león', 2),
#  ('El caballero de la soledad', 2),
#  ('El camino hacia la oscuridad', 2),
#  ('La travesura de el amanecer', 2),
#  ('El amanecer de la bailarina', 2),
#  ('El regreso de la noche', 2),
#  ('La danza de la tormenta', 2),
#  ('El regreso de la caverna', 2),
#  ('La llegada de la criatura', 2),
#  ('La cripta de la bailarina', 2),
#  ('El secreto de la montaña', 2),
#  ('La odisea de la reina', 2),
#  ('El caballero de la caída', 2),
#  ('El regreso de la escuela', 2),
#  ('La leyenda perdida de la salvación', 2),
#  ('La travesía sin retorno de el viaje', 2),
#  ('La travesía sin retorno de la escuela', 2),
#  ('La búsqueda de el renacimiento', 2),
#  ('La travesura de el faro', 2),
#  ('La invasión de la paz', 2),
#  ('El tesoro escondido de el guerrero', 2),
#  ('El tesoro escondido de la fortuna', 2),
#  ('El guardián de la clave', 2),
#  ('El resurgimiento de el río', 2),
#  ('La historia de el explorador', 2),
#  ('La venganza de la bienvenida', 2),
#  ('El vuelo de el explorador', 2),
#  ('El tesoro escondido de el valle', 2),
#  ('El renacimiento de el grito', 2),
#  ('El eclipse de la puerta', 2),
#  ('El eclipse de la batalla', 2),
#  ('El cuento de hadas de la isla', 2),
#  ('El renacimiento de el lamento', 2),
#  ('La rebelión de el desafío', 2),
#  ('El despertar de la magia', 2),
#  ('La redención de la mariposa', 2),
#  ('La fuga de la cascada', 2),
#  ('El secreto de el castillo', 2),
#  ('El regreso de la magia', 2),
#  ('El arco iris de la tormenta', 2),
#  ('La búsqueda de el misterio', 2),
#  ('La búsqueda del tesoro de la tierra', 2),
#  ('La danza de la pasión', 2),
#  ('La rebelión de la corrupción', 2),
#  ('El tesoro de el castillo', 2),
#  ('El canto de sirena de la compañía', 2),
#  ('La cripta de la cripta', 2),
#  ('El descubrimiento de el puente', 2),
#  ('El prisionero de la batalla', 2),
#  ('El secreto de la bestia', 2),
#  ('El espejismo de la princesa', 2),
#  ('La travesía del océano de la pesadilla', 2),
#  ('La metamorfosis de la oscuridad', 2),
#  ('El eclipse de el volcán', 2),
#  ('La conquista de la cripta', 2),
#  ('La canción de el volcán', 2),
#  ('La leyenda de la academia', 2),
#  ('La fuga de la paz', 2),
#  ('La llegada de la corrupción', 2),
#  ('La fortuna de el pacto', 2),
#  ('La resurrección de la escuela', 2),
#  ('La trampa de la estrella', 2),
#  ('La travesía de el sol', 2),
#  ('El prisionero de la tierra', 2),
#  ('El destino de el ángel', 2)]

# %% [markdown]
# ### Consulta 6
# **Nombre de la película con la mayor brecha de edad entre el actor más joven y el actor más viejo que participen en ella, y las edades de dichos actores.** (Si hay empate, mostrar solamente uno).
#
#
# **Ejemplo:**
# |Nombre|Edad del actor más joven|Edad del actor más viejo|
# |------|------------------------|------------------------|
# |Barbie|16                      |92                      |
#
#
# **Solución:**
# Primero, como necesitamos el nombre de la pelicula y la edad de los actores que participen en ellas, hacemos uso de INNER JOIN, usando los ids de las tablas originales como condición para unir y coincidir la información con la de la tabla actor_participa_en_pelicula. Con eso listo, podemos agrupar de acuerdo al id_pelicula de la tabla película y luego ordenar descendientemente de acuerdo a que película tiene la mayor brecha de edad entre sus actores. Finalmente, al poner LIMIT 1, nos aseguramos de que incluso habiendo un empate, solo se seleccionará la primera fila.

# %%
# %%sql
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */
#
# SELECT
#     pelicula.nombre AS "Nombre",
#     MIN(actor.edad) AS "Edad del actor más joven",
#     MAX(actor.edad) AS "Edad del actor más viejo"
# FROM
#     actor_participa_en_pelicula
# INNER JOIN actor ON actor_participa_en_pelicula.id_actor = actor.id_actor
# INNER JOIN pelicula ON actor_participa_en_pelicula.id_pelicula = pelicula.id_pelicula
# GROUP BY
#     pelicula.id_pelicula
# ORDER BY
#     (MAX(actor.edad) - MIN(actor.edad)) DESC
# LIMIT 1;
# Out:
#  * postgresql://Grupo6:***@localhost:5433/tareabd1
# 1 rows affected.
# [('La travesura de el faro', 17, 69)]

# %% [markdown]
# ### Consulta 7
# **Año de cada premio ganado por la película de mayor duración.** (Si hay empate, elegir solamente uno).
#
#
# **Ejemplo:**
# |Año |
# |----|
# |2024|
# |... |
#
#
# **Solución:** _Primero buscamos los id_pelicula dentro de la tabla pelicula que coincidan con la máxima duración, pero solo guardamos 1. Con esta tabla, realizamos un inner join con la tabla premio_mejor_pelicula con el objetivo de encontrar los años en los que este id_pelicula fue premiado._

# %%
# %%sql
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */
# SELECT
#     premio_mejor_pelicula.anio AS "Año"
# FROM
#     (
#         SELECT
#             id_pelicula
#         FROM
#             pelicula
#         WHERE
#             duracion = (SELECT MAX(duracion) FROM pelicula)
#         LIMIT 1
#     ) AS maxima_duracion INNER JOIN
#     premio_mejor_pelicula ON premio_mejor_pelicula.id_pelicula = maxima_duracion.id_pelicula
# ORDER BY
#     premio_mejor_pelicula.anio;
# Out:
#  * postgresql://Grupo6:***@localhost:5433/tareabd1
# 0 rows affected.
# []

# %% [markdown]
# ### Consulta 8
# **Nombre de todos los actores que han trabajado con más de un director, la cantidad de directores con las que han trabajado y el nombre de una de las películas.**
#
#
# **Ejemplo:**
# |Nombre del actor|Cantidad de directores|Nombre de una película|
# |----------------|----------------------|----------------------|
# |Cillian Murphy  |29                    |Oppenheimer           |
# |...             |...                   |...                   |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */
# SELECT
#     actor.nombre AS "Nombre del actor",
#     COUNT(DISTINCT director.id_director) AS "Cantidad de directores",
#     MAX(pelicula.nombre) AS "Nombre de una película"
# FROM
#     actor
#     INNER JOIN actor_participa_en_pelicula ON actor.id_actor = actor_participa_en_pelicula.id_actor
#     INNER JOIN pelicula ON actor_participa_en_pelicula.id_pelicula = pelicula.id_pelicula
#     INNER JOIN director ON pelicula.id_director = director.id_director
# GROUP BY
#     actor.id_actor
# HAVING
#     COUNT(DISTINCT director.id_director) > 1
# ORDER BY
#     "Cantidad de directores" DESC
# ;
# Out:
#  * postgresql://Grupo6:***@localhost:5433/tareabd1
# 144 rows affected.
# [('Oscar Ortega', 7, 'La metamorfosis de la tormenta'),
#  ('Qiu Ortega', 7, 'La trampa de la criatura'),
#  ('Chen Esteves', 6, 'La travesía de el sol'),
#  ('Emiko Cruz', 6, 'La travesía del océano de la bestia'),
#  ('Bianca Inácio', 6, 'La rebelión de el tesoro'),
#  ('Valentina Ferreira', 6, 'La trampa de la estrella'),
#  ('Bianca Hernandez', 5, 'La invasión de la paz'),
#  ('Rosa Vieira', 5, 'La resurrección de la sombra'),
#  ('Zara Oliveira', 5, 'La cripta de el valle'),
#  ('Rashid Iglesias', 5, 'La leyenda perdida de la trampa'),
#  ('Elena Joaquim', 5, 'La leyenda de la corrupción'),
#  ('Beatriz Almeida', 5, 'Las aventuras de el secreto'),
#  ('Ursula Uchoa', 5, 'La rebelión de la corrupción'),
#  ('Wang Duarte', 5, 'La fortuna de el pacto'),
#  ('Umar Hidalgo', 5, 'La tormenta de el dragón'),
#  ('Javier Quintana', 5, 'La misión de el sol'),
#  ('Yuri Estevez', 5, 'La travesía sin retorno de la escuela'),
#  ('Xavier Rodriguez', 5, 'La travesía sin retorno de el rincón'),
#  ('Rania Vieira', 5, 'La travesía sin retorno de la escuela'),
#  ('Pilar Dutta', 5, 'La resurrección de el león'),
#  ('Natalia Hernandez', 5, 'La travesura de la flor'),
#  ('Mikhail Diniz', 4, 'La llegada de la corrupción'),
#  ('Quintus Uchoa', 4, 'La venganza de la estrella fugaz'),
#  ('Mehmet Watanabe', 4, 'La maldición de la cascada'),
#  ('Gustavo Etxebarria', 4, 'La llegada de la criatura'),
#  ('Leticia Esteves', 4, 'La llave de el sueño'),
#  ('Patricia Borges', 4, 'La redención de la mariposa'),
#  ('Oscar Xia', 4, 'La rebelión de el desafío'),
#  ('Isa Watanabe', 4, 'La travesía del océano de el abismo'),
#  ('Hanako Ferreira', 4, 'La fuente de el puente'),
#  ('Kamala Inácio', 4, 'La travesura de la flor'),
#  ('Zafar Ivanov', 4, 'La metamorfosis de la oscuridad'),
#  ('Mehmet Lopez', 4, 'La venganza de la esperanza'),
#  ('Lakshmi Lopez', 4, 'La venganza de la estrella fugaz'),
#  ('Giovanni Rodriguez', 4, 'La danza de la noche'),
#  ('Umberto Yan', 4, 'La metamorfosis de la oscuridad'),
#  ('Leticia Xia', 4, 'La leyenda de la corrupción'),
#  ('Umberto Tan', 4, 'La metamorfosis de la tormenta'),
#  ('Javier Janssen', 4, 'La trampa de la pesadilla'),
#  ('Gustavo Figueiredo', 4, 'La trampa de la cárcel'),
#  ('Han Nguyen', 4, 'La travesura de el secreto'),
#  ('Beatriz Tan', 4, 'La travesía sin retorno de el rincón'),
#  ('Wan Pereira', 4, 'La travesura de la bestia'),
#  ('Quentin Quintana', 4, 'La trampa de la criatura'),
#  ('Fabiana Vieira', 4, 'La venganza de la esperanza'),
#  ('Kamala Oliveira', 4, 'La escalada de el mar'),
#  ('Chidike Rodriguez', 4, 'La fuga de la paz'),
#  ('Natalia Rocha', 4, 'La travesía sin retorno de la estrella'),
#  ('Genghis Zambrano', 3, 'La leyenda de la corrupción'),
#  ('Akira Fernandes', 3, 'La trampa de la estrella'),
#  ('Darius Nguyen', 3, 'La estirpe de la gárgola'),
#  ('Oscar Duarte', 3, 'La tormenta de la profecía'),
#  ('Nina Almeida', 3, 'La escalada de el mar'),
#  ('Giovanni Ortega', 3, 'La travesía sin retorno de el rincón'),
#  ('Quintus Kumar', 3, 'La travesía de el valle'),
#  ('Tatiana Xia', 3, 'La trampa de el guardián'),
#  ('Xin Zambrano', 3, 'La tormenta de el árbol'),
#  ('Fabiana Cruz', 3, 'La trampa de la criatura'),
#  ('Katarina Etxebarria', 3, 'La travesura de la bestia'),
#  ('Zara Goncalves', 3, 'La rebelión de la corrupción'),
#  ('Valeria Correia', 3, 'La leyenda perdida de la maraña'),
#  ('Quintus Wu', 3, 'La metamorfosis de la tormenta'),
#  ('Hanako Yan', 3, 'El ritual de la fortuna'),
#  ('Isa Ramos', 3, 'La travesía sin retorno de el viaje'),
#  ('Zara Yamamoto', 3, 'El tesoro escondido de la fortuna'),
#  ('Yusef Watanabe', 3, 'El vuelo de el explorador'),
#  ('Umar Uchoa', 3, 'La leyenda perdida de la tormenta'),
#  ('Orhan Kumar', 3, 'La metamorfosis de el monstruo'),
#  ('Fadhila Estevez', 3, 'La travesía sin retorno de el rincón'),
#  ('Isa Xu', 3, 'La invasión de la bruma'),
#  ('Orhan Velez', 3, 'La travesura de el faro'),
#  ('Xavier Xu', 3, 'La resurrección de la escuela'),
#  ('Alessandro Lopes', 3, 'La tormenta de la fortuna'),
#  ('Zara Zambrano', 3, 'La maldición del vampiro de el abismo'),
#  ('Irina Tan', 3, 'La trampa de el guardián'),
#  ('Xin Montenegro', 3, 'La batalla de el vuelo'),
#  ('Elif Wu', 3, 'La fuga de la cascada'),
#  ('Xin Fernandes', 3, 'La leyenda perdida de la tormenta'),
#  ('Fabiana Yilmaz', 3, 'La metamorfosis de la bestia'),
#  ('Bianca Yilmaz', 3, 'La maldición del vampiro de la muralla'),
#  ('Wilhelmina Pereira', 3, 'La venganza de la bienvenida'),
#  ('Xavier Sousa', 3, 'El prisionero de la venganza'),
#  ('Nina Kumar', 3, 'La historia de el explorador'),
#  ('Elif Yilmaz', 3, 'La danza de la tormenta'),
#  ('Dmitri Petrov', 3, 'La batalla de la montaña'),
#  ('Umberto Petrov', 3, 'La venganza de la cascada'),
#  ('Oscar Estevez', 3, 'La danza de la noche'),
#  ('Chidike Lopez', 3, 'La danza de la tormenta'),
#  ('Bianca Esteves', 3, 'La travesura de la cueva'),
#  ('Salim Kawaguchi', 3, 'La travesía del océano de la estrella'),
#  ('Genghis Yilmaz', 3, 'La batalla de el lamento'),
#  ('Qiu Carvalho', 3, 'El refugio de la guerra'),
#  ('Tatiana Barros', 2, 'La estirpe de la gárgola'),
#  ('Dmitri Sousa', 2, 'El último viaje de la pesadilla'),
#  ('Oscar Quintana', 2, 'La travesía del océano de la esperanza'),
#  ('Yusef Yamamoto', 2, 'La trampa de el guardián'),
#  ('Zafar Ortega', 2, 'La travesura de el faro'),
#  ('Theresa Velez', 2, 'La búsqueda de el renacimiento'),
#  ('Aarav Jimenez', 2, 'La batalla de la montaña'),
#  ('Jasmin Inácio', 2, 'El refugio de la guerra'),
#  ('Fabiana Diniz', 2, 'La cripta de la bailarina'),
#  ('Xin Janssen', 2, 'La leyenda perdida de la neblina'),
#  ('Mina Almeida', 2, 'El viajero de el laberinto'),
#  ('Alessandro Fernandes', 2, 'La búsqueda del tesoro de la batalla'),
#  ('Qiu Gomes', 2, 'La maldición del vampiro de la muralla'),
#  ('Jin Hernandez', 2, 'La resurrección de el guardián'),
#  ('Hanako Yan', 2, 'La travesía sin retorno de el rincón'),
#  ('Valentina Pacheco', 2, 'La venganza de la bienvenida'),
#  ('Rosa Xu', 2, 'El refugio de el río'),
#  ('Qiu Velez', 2, 'La trampa de la pesadilla'),
#  ('Javier Ueno', 2, 'El regreso de la caverna'),
#  ('Nadia Barros', 2, 'La rebelión de el desafío'),
#  ('Fabiana Santos', 2, 'El bosque encantado de la promesa'),
#  ('Emiko Carvalho', 2, 'La búsqueda de el renacimiento'),
#  ('Pilar Jimenez', 2, 'La escalada de el enigma'),
#  ('Darya Zapata', 2, 'La leyenda de la academia'),
#  ('Darya Inácio', 2, 'La resurrección de el guardián'),
#  ('Wan Yilmaz', 2, 'El renacimiento de el legado'),
#  ('Yusef Watanabe', 2, 'La trampa de la criatura'),
#  ('Samir Zapata', 2, 'La odisea de la reina'),
#  ('Jin Lima', 2, 'La leyenda perdida de la salvación'),
#  ('Jin Tan', 2, 'El regreso de la caverna'),
#  ('Wilhelmina Ivanov', 2, 'La llave de el sueño'),
#  ('Wang Kawaguchi', 2, 'La batalla de el castillo'),
#  ('Aarav Zambrano', 2, 'El tesoro de el castillo'),
#  ('Javier Zambrano', 2, 'La cripta de la cripta'),
#  ('Valeria Almeida', 2, 'La tormenta de el dragón'),
#  ('Oscar Bianchi', 2, 'La canción de el volcán'),
#  ('Mina Santana', 2, 'La fuente de la perdición'),
#  ('Orhan Zhang', 2, 'La travesura de el amanecer'),
#  ('Darius Ivanov', 2, 'La batalla de el vuelo'),
#  ('Valeria Gao', 2, 'La travesura de el secreto'),
#  ('Valeria Qian', 2, 'La búsqueda de el fuego'),
#  ('Leticia Rodriguez', 2, 'La leyenda perdida de el laberinto'),
#  ('Umar Diniz', 2, 'La doncella de la flor'),
#  ('Zoya Watanabe', 2, 'La resurrección de la sombra'),
#  ('Wilhelmina Kumar', 2, 'El pacto de el tesoro'),
#  ('Wan Martinez', 2, 'La redención de la mariposa'),
#  ('Rosa Lima', 2, 'La estrella fugaz de el viaje'),
#  ('Wan Estevez', 2, 'La estirpe de la gárgola'),
#  ('Samir Yamamoto', 2, 'La travesura de la bestia'),
#  ('Darya Yamamoto', 2, 'La batalla de el castillo'),
#  ('Alessandro Almeida', 2, 'La estrella fugaz de la ola'),
#  ('Wilhelmina Ivanov', 2, 'La canción de el volcán')]

# %% [markdown]
# ### Consulta 9
#
# **Nombre de todos los actores que han participado sólo en películas dirigidas por el director con id\_director 1.**
#
#
# **Ejemplo:**
# |Nombre      |
# |------------|
# |Ryan Gosling|
# |...         |
#
#
# **Solución:**
# Primero, con el INNER JOIN aplicado a actor_participa_en_pelicula y película segregamos los ids de los actores donde se cumpla la condición dada, en este caso, que el id del director de dicha pelicula sea 1, teniendo estos ids, relacionamos con la tabla actor, bajo la condición actor.id_actor = act_dir.id_act, obteniendo finalmente la tabla con

# %%
# %%sql
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */
# SELECT
#     actor.nombre AS "Nombre"
# FROM
#     actor,
#     (SELECT
#         actor_participa_en_pelicula.id_actor as id_act
#     FROM actor_participa_en_pelicula
#     INNER JOIN pelicula ON actor_participa_en_pelicula.id_pelicula=pelicula.id_pelicula
#     WHERE
#         pelicula.id_director = 1 )AS act_dir
# WHERE
#     actor.id_actor = act_dir.id_act
#  ;
# Out:
#  * postgresql://Grupo6:***@localhost:5433/tareabd1
# 5 rows affected.
# [('Mina Rodriguez',),
#  ('Natalia Rocha',),
#  ('Beatriz Almeida',),
#  ('Umar Uchoa',),
#  ('Kamala Inácio',)]

# %% [markdown]
# ### Consulta BONUS
#
# **Nombre de todos los actores que nunca han ganado un premio, todas las películas en las que han participado y el nombre, número total de películas y número total de premios de los directores de cada película.**
#
#
# **Ejemplo:**
# |Nombre del actor|Nombre de la película|Nombre del director|Número de películas del director|Número de premios del director|
# |----------------|---------------------|-------------------|--------------------------------|-----------------------|
# |Mark Ruffalo    |Poor Things          |Yorgos Lanthimos   |4                               |0                      |
# |Saoirse Ronan   |Lady Bird            |Greta Gerwig       |20                              |1                      |
# |Saoirse Ronan   |Little Women         |Greta Gerwig       |20                              |1                      |
# |...             |...                  |...                |...                             |...                    |
#
#
# **Solución:** _Para poder realizar esta consulta lo vamos a dividir en distintos pasos: primero, realizamos un left join de la tabla actor con la tabla premio_mejor_actor, y filtramos todos los actores que no tengan asignados ningún premio; segundo, con esta tabla, realizamos un inner join con la tabla actor_participa_en_pelicula, de esta forma encontramos todos los id_pelicula en las que han participado los actores; tercero, realizamos un inner join a la tabla película, con esto podemos acceder a los nombres de las películas y los id_director; cuarto, realizamos una consulta para contar cuantos premios ha ganado cada director, para conseguir esto, simplemente realizamos un left join de la tabla director con la tabla premio_mejor_director, y nos quedamos con los id_director, los nombres de los directores y con la cantidad de premios de cada director, esta tabla le hacemos inner join con lo que tenemos hasta el paso anterior; quinto, similar al paso anterior, realizamos una consulta, para contar en cuantas películas ha participado el director, para esto realizamos un left join de la tabla director y la tabla pelicula, y contamos la cantidad de películas; sexto y último paso, simplemente consultamos de la tabla resultante el nombre del actor, el nombre de la película, el nombre del director, el número de películas del director, y el número de premios del director._

# %%
# %%sql
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */
#
# SELECT
#     actor.nombre AS "Nombre del actor",
#     pelicula.nombre AS "Nombre de la película",
#     cnt_director.nombre AS "Nombre del director",
#     cnt_peli.cantidad AS "Número de películas del director",
#     cnt_director.frecuencia AS "Número de premios del director"
# FROM
#     actor LEFT JOIN premio_mejor_actor ON actor.id_actor = premio_mejor_actor.id_actor
#     INNER JOIN actor_participa_en_pelicula ON actor.id_actor = actor_participa_en_pelicula.id_actor
#     INNER JOIN pelicula ON actor_participa_en_pelicula.id_pelicula = pelicula.id_pelicula
#     INNER JOIN (
#         SELECT
#             COUNT(premio_mejor_director.id_director) AS frecuencia,
#             director.id_director,
#             director.nombre
#             FROM
#                 director LEFT JOIN
#                 premio_mejor_director ON director.id_director = premio_mejor_director.id_director
#             GROUP BY
#                 director.id_director,
#                 director.nombre
#     ) AS cnt_director ON pelicula.id_director = cnt_director.id_director
#     INNER JOIN (
#         SELECT
#             COUNT(*) AS cantidad,
#             director.id_director
#         FROM
#             director LEFT JOIN pelicula ON director.id_director = pelicula.id_director
#         GROUP BY
#             director.id_director
#     ) AS cnt_peli ON cnt_peli.id_director = cnt_director.id_director
# WHERE
#     premio_mejor_actor.id_actor IS NULL
# ORDER BY
#     actor.id_actor;
# Out:
#  * postgresql://Grupo6:***@localhost:5433/tareabd1
# 399 rows affected.
# [('Valeria Correia', 'El descubrimiento de el puente', 'Umberto Olivares', 2, 0),
#  ('Valeria Correia', 'El cuento de hadas de la isla', 'Jasmin Santos', 2, 1),
#  ('Valeria Correia', 'La leyenda perdida de la maraña', 'Valeria Xia', 1, 0),
#  ('Valentina Pacheco', 'El pacto de la aldea', 'Rosa Xavier', 1, 0),
#  ('Valentina Pacheco', 'La venganza de la bienvenida', 'Pilar Urbina', 3, 0),
#  ('Mina Almeida', 'El secreto de la bestia', 'Aarav Ramos', 3, 0),
#  ('Mina Almeida', 'El viajero de el laberinto', 'Leticia Fernandes', 4, 0),
#  ('Theresa Velez', 'El renacimiento de el legado', 'Parvati Olivares', 3, 0),
#  ('Theresa Velez', 'La búsqueda de el renacimiento', 'Yuri Ortega', 1, 1),
#  ('Umar Diniz', 'La doncella de la flor', 'Akira Montenegro', 2, 0),
#  ('Umar Diniz', 'El hechizo de el laberinto', 'Zafar Xavier', 1, 0),
#  ('Gustavo Etxebarria', 'El tesoro escondido de la ley', 'Mina Yan', 2, 0),
#  ('Gustavo Etxebarria', 'El camino hacia la oscuridad', 'Irina Sousa', 3, 2),
#  ('Gustavo Etxebarria', 'El príncipe de la pesadilla', 'Elif Tan', 3, 0),
#  ('Gustavo Etxebarria', 'La llegada de la criatura', 'Omar Uchoa', 2, 0),
#  ('Nadia Iglesias', 'La batalla de la ciudad', 'Sakura Lima', 2, 0),
#  ('Javier Xu', 'La maldición del vampiro de la selva', 'Alessandro Pereira', 1, 0),
#  ('Kamala Inácio', 'La travesura de la flor', 'Valentina Martinez', 2, 0),
#  ('Kamala Inácio', 'La fortuna de la batalla', 'Dmitri Nguyen', 3, 0),
#  ('Kamala Inácio', 'El hechizo de la salvación', 'Kamala Vargas', 2, 0),
#  ('Kamala Inácio', 'La travesía sin retorno de la estrella', 'Lakshmi Jimenez', 2, 0),
#  ('Wang Kawaguchi', 'La batalla de el castillo', 'Parvati Olivares', 3, 0),
#  ('Wang Kawaguchi', 'El resurgimiento de el río', 'Beatriz Xia', 3, 0),
#  ('Akira Fernandes', 'El refugio de el río', 'Fadhila Yilmaz', 2, 0),
#  ('Akira Fernandes', 'La trampa de la estrella', 'Umar Mendes', 5, 1),
#  ('Akira Fernandes', 'La metamorfosis de la tormenta', 'Umar Mendes', 5, 1),
#  ('Akira Fernandes', 'El laberinto de la sonrisa', 'Omar Nguyen', 4, 0),
#  ('Darius Nguyen', 'El eclipse de la puerta', 'Jasmin Cruz', 1, 0),
#  ('Darius Nguyen', 'El viajero de el laberinto', 'Tatjana Pereira', 3, 0),
#  ('Darius Nguyen', 'La estirpe de la gárgola', 'Hiroko Sousa', 2, 1),
#  ('Oscar Duarte', 'El laberinto de la sonrisa', 'Omar Nguyen', 4, 0),
#  ('Oscar Duarte', 'El caballero de la verdad', 'Alessandro Queiroz', 1, 0),
#  ('Oscar Duarte', 'La tormenta de la profecía', 'Dmitri Nguyen', 3, 0),
#  ('Xavier Rodriguez', 'La maldición del vampiro de la muralla', 'Gustavo Zhang', 2, 0),
#  ('Xavier Rodriguez', 'El eclipse de la ola', 'Fadhila Xavier', 1, 0),
#  ('Xavier Rodriguez', 'La travesía sin retorno de el rincón', 'Zara Estevez', 3, 0),
#  ('Xavier Rodriguez', 'La leyenda perdida de la maraña', 'Valeria Xia', 1, 0),
#  ('Xavier Rodriguez', 'El prisionero de la batalla', 'Hiroko Sousa', 2, 1),
#  ('Chidike Rodriguez', 'El secreto de el castillo', 'Mina Yan', 2, 0),
#  ('Chidike Rodriguez', 'El prisionero de la tierra', 'Umar Mendes', 5, 1),
#  ('Chidike Rodriguez', 'La fuga de la paz', 'Irina Lopes', 1, 0),
#  ('Chidike Rodriguez', 'El destino de la sirena', 'Yasmin Queiroz', 2, 0),
#  ('Yusef Gomes', 'El amanecer de la pesadilla', 'Elena Almeida', 3, 0),
#  ('Jin Lima', 'El refugio de la guerra', 'Beatriz Cruz', 2, 0),
#  ('Jin Lima', 'La leyenda perdida de la salvación', 'Jasmin Iglesias', 2, 0),
#  ('Lakshmi Lopez', 'El ritual de la fortuna', 'Beatriz Teixeira', 2, 1),
#  ('Lakshmi Lopez', 'La venganza de la estrella fugaz', 'Dmitri Velez', 1, 0),
#  ('Lakshmi Lopez', 'El eclipse de el volcán', 'Jin Zhang', 1, 0),
#  ('Lakshmi Lopez', 'La danza de la noche', 'Vivek Ortega', 4, 0),
#  ('Emiko Cruz', 'La trampa de el guardián', 'Oscar Wu', 2, 0),
#  ('Emiko Cruz', 'La fuga de la cascada', 'Beatriz Xia', 3, 0),
#  ('Emiko Cruz', 'El viajero de la maraña', 'Kamala Yan', 3, 0),
#  ('Emiko Cruz', 'La leyenda de el explorador', 'Umar Mendes', 5, 1),
#  ('Emiko Cruz', 'La travesía del océano de la bestia', 'Elif Urbina', 5, 0),
#  ('Emiko Cruz', 'El lamento de el caos', 'Elif Montenegro', 2, 0),
#  ('Emiko Cruz', 'El caballero de la despedida', 'Kamala Yan', 3, 0),
#  ('Bianca Hernandez', 'La invasión de la bruma', 'Sakura Lima', 2, 0),
#  ('Bianca Hernandez', 'La fuente de la tormenta', 'Mikhail Uchoa', 4, 1),
#  ('Bianca Hernandez', 'La invasión de la paz', 'Samir Xavier', 2, 1),
#  ('Bianca Hernandez', 'El regreso de la escuela', 'Ximena Nogueira', 1, 0),
#  ('Bianca Hernandez', 'La danza de la pasión', 'Omar Nguyen', 4, 0),
#  ('Gustavo Figueiredo', 'La trampa de la cárcel', 'Wan Lopez', 1, 0),
#  ('Gustavo Figueiredo', 'El príncipe de la pesadilla', 'Elif Tan', 3, 0),
#  ('Gustavo Figueiredo', 'El viajero de el laberinto', 'Leticia Fernandes', 4, 0),
#  ('Gustavo Figueiredo', 'La búsqueda de el hechizo', 'Leticia Diniz', 4, 0),
#  ('Nina Almeida', 'El ritual de la luna', 'Omar Uchoa', 2, 0),
#  ('Nina Almeida', 'La escalada de el mar', 'Zoya Martinez', 5, 1),
#  ('Nina Almeida', 'El refugio de la estrella fugaz', 'Rashid Janssen', 2, 0),
#  ('Wan Yilmaz', 'El renacimiento de el legado', 'Parvati Olivares', 3, 0),
#  ('Wan Yilmaz', 'El laberinto de la sonrisa', 'Omar Nguyen', 4, 0),
#  ('Darya Inácio', 'La estrella fugaz de la ola', 'Leticia Fernandes', 4, 0),
#  ('Darya Inácio', 'La resurrección de el guardián', 'Han Ueno', 3, 1),
#  ('Giovanni Ortega', 'La fuga de la paz', 'Irina Lopes', 1, 0),
#  ('Giovanni Ortega', 'La travesía sin retorno de el rincón', 'Zara Estevez', 3, 0),
#  ('Giovanni Ortega', 'La resurrección de la sombra', 'Giovanni Barros', 3, 0),
#  ('Darya Zapata', 'La leyenda de la academia', 'Giovanni Velez', 1, 0),
#  ('Darya Zapata', 'El viaje de la resistencia', 'Ilya Duarte', 3, 1),
#  ('Tatiana Xia', 'La trampa de el guardián', 'Oscar Wu', 2, 0),
#  ('Tatiana Xia', 'El despertar de la sirena', 'Elena Almeida', 3, 0),
#  ('Tatiana Xia', 'La estrella fugaz de la ola', 'Leticia Fernandes', 4, 0),
#  ('Ilya Kawaguchi', 'El viaje de la resistencia', 'Ilya Duarte', 3, 1),
#  ('Fadhila Uchoa', 'La travesía del océano de la pesadilla', 'Wilhelmina Lima', 2, 0),
#  ('Chen Estevez', 'La escalada de el enigma', 'Zara Hidalgo', 1, 0),
#  ('Nadia Barros', 'El secreto de el castillo', 'Mina Yan', 2, 0),
#  ('Nadia Barros', 'La rebelión de el desafío', 'Elena Almeida', 3, 0),
#  ('Rosa Xu', 'El refugio de el río', 'Fadhila Yilmaz', 2, 0),
#  ('Rosa Xu', 'El laberinto de la sonrisa', 'Omar Nguyen', 4, 0),
#  ('Fadhila Nguyen', 'La leyenda de la pesadilla', 'Wan Esteves', 2, 0),
#  ('Xin Zambrano', 'La estrella fugaz de la sirena', 'Hanako Martinez', 2, 0),
#  ('Xin Zambrano', 'La tormenta de el árbol', 'Emiko Zapata', 1, 0),
#  ('Xin Zambrano', 'La búsqueda del tesoro de la tierra', 'Genghis Diniz', 1, 0),
#  ('Xin Janssen', 'La doncella de la guerra', 'Elena Iglesias', 5, 2),
#  ('Xin Janssen', 'La leyenda perdida de la neblina', 'Zoya Nguyen', 4, 0),
#  ('Fabiana Cruz', 'La trampa de la criatura', 'Omar Uchoa', 2, 0),
#  ('Fabiana Cruz', 'El laberinto de la aldea', 'Omar Uchoa', 2, 0),
#  ('Fabiana Cruz', 'El destino de la desgracia', 'Elif Barros', 1, 0),
#  ('Rashid Montenegro', 'El prisionero de la batalla', 'Hiroko Sousa', 2, 1),
#  ('Katarina Etxebarria', 'El lamento de la aldea', 'Hanako Teixeira', 1, 0),
#  ('Katarina Etxebarria', 'La travesía del océano de la estrella', 'Orhan Goncalves', 2, 0),
#  ('Katarina Etxebarria', 'La travesura de la bestia', 'Omar Fernandes', 3, 0),
#  ('Zara Goncalves', 'El bosque encantado de la leyenda', 'Valeria Petrov', 2, 0),
#  ('Zara Goncalves', 'El renacimiento de el legado', 'Parvati Olivares', 3, 0),
#  ('Zara Goncalves', 'La rebelión de la corrupción', 'Chen Inácio', 2, 0),
#  ('Mikhail Zapata', 'La estirpe de la batalla', 'Fabiana Xu', 2, 1),
#  ('Genghis Zambrano', 'El castillo de la heroína', 'Theresa Velez', 2, 1),
#  ('Genghis Zambrano', 'El prisionero de la tierra', 'Umar Mendes', 5, 1),
#  ('Genghis Zambrano', 'La leyenda de la corrupción', 'Qiu Pacheco', 3, 0),
#  ('Chen Etxebarria', 'El destino de el ángel', 'Jin Almeida', 1, 0),
#  ('Quintus Wu', 'El laberinto de la ola', 'Elif Urbina', 5, 0),
#  ('Quintus Wu', 'El bosque encantado de el lamento', 'Khaled Pereira', 2, 0),
#  ('Quintus Wu', 'La metamorfosis de la tormenta', 'Umar Mendes', 5, 1),
#  ('Hanako Yan', 'El hechizo de el laberinto', 'Zafar Xavier', 1, 0),
#  ('Hanako Yan', 'El destino de el destino', 'Aarav Ortega', 2, 1),
#  ('Hanako Yan', 'El ritual de la fortuna', 'Beatriz Teixeira', 2, 1),
#  ('Dmitri Sousa', 'El amanecer de la pesadilla', 'Elena Almeida', 3, 0),
#  ('Dmitri Sousa', 'El último viaje de la pesadilla', 'Beatriz Rodriguez', 1, 0),
#  ('Lakshmi Rodriguez', 'La odisea de la reina', 'Quentin Quintana', 1, 0),
#  ('Wilhelmina Ivanov', 'La canción de el volcán', 'Darya Gomes', 2, 0),
#  ('Wilhelmina Ivanov', 'El laberinto de la ola', 'Elif Urbina', 5, 0),
#  ('Zafar Ivanov', 'El espejismo de la princesa', 'Genghis Sousa', 2, 0),
#  ('Zafar Ivanov', 'El lamento de el caos', 'Elif Montenegro', 2, 0),
#  ('Zafar Ivanov', 'La metamorfosis de la oscuridad', 'Leticia Yamamoto', 3, 0),
#  ('Zafar Ivanov', 'La historia de el laberinto', 'Han Ueno', 3, 1),
#  ('Alessandro Almeida', 'La estrella fugaz de la ola', 'Leticia Fernandes', 4, 0),
#  ('Alessandro Almeida', 'El amanecer de la pesadilla', 'Elena Almeida', 3, 0),
#  ('Rania Vieira', 'La búsqueda de la montaña', 'Kamala Gomes', 1, 0),
#  ('Rania Vieira', 'La resurrección de la escuela', 'Darya Uchoa', 2, 0),
#  ('Rania Vieira', 'La travesía del océano de la estrella', 'Orhan Goncalves', 2, 0),
#  ('Rania Vieira', 'La estrella fugaz de el viaje', 'Fadhila Quintana', 1, 0),
#  ('Rania Vieira', 'La travesía sin retorno de la escuela', 'Irina Sousa', 3, 2),
#  ('Isa Ramos', 'La doncella de el atardecer', 'Omar Nguyen', 4, 0),
#  ('Isa Ramos', 'La estrella fugaz de la ola', 'Leticia Fernandes', 4, 0),
#  ('Isa Ramos', 'La travesía sin retorno de el viaje', 'Wang Watanabe', 1, 0),
#  ('Pilar Dutta', 'La resurrección de el león', 'Ximena Gomes', 1, 0),
#  ('Pilar Dutta', 'El arco iris de la tormenta', 'Genghis Oliveira', 1, 0),
#  ('Pilar Dutta', 'La estirpe de la estrella fugaz', 'Akira Montenegro', 2, 0),
#  ('Pilar Dutta', 'El destino de la aventura', 'Kamala Teixeira', 3, 0),
#  ('Pilar Dutta', 'La leyenda de la academia', 'Giovanni Velez', 1, 0),
#  ('Zara Yamamoto', 'El tesoro escondido de la fortuna', 'Zoya Martinez', 5, 1),
#  ('Zara Yamamoto', 'El hechizo de el laberinto', 'Zafar Xavier', 1, 0),
#  ('Zara Yamamoto', 'El caballero de la muralla', 'Umar Zhang', 1, 0),
#  ('Yusef Watanabe', 'El eclipse de la batalla', 'Elif Urbina', 5, 0),
#  ('Yusef Watanabe', 'El vuelo de el explorador', 'Qiu Wu', 3, 0),
#  ('Yusef Watanabe', 'El tesoro escondido de el valle', 'Javier Alvarez', 3, 1),
#  ('Wan Estevez', 'La estirpe de la gárgola', 'Hiroko Sousa', 2, 1),
#  ('Wan Estevez', 'La conquista de la cripta', 'Wan Nunes', 3, 0),
#  ('Zoya Watanabe', 'El hechizo de la salvación', 'Kamala Vargas', 2, 0),
#  ('Zoya Watanabe', 'La resurrección de la sombra', 'Giovanni Barros', 3, 0),
#  ('Wan Pereira', 'La fuente de la pasión', 'Elif Urbina', 5, 0),
#  ('Wan Pereira', 'El espejismo de la leyenda', 'Jasmin Santos', 2, 1),
#  ('Wan Pereira', 'El castillo de la heroína', 'Theresa Velez', 2, 1),
#  ('Wan Pereira', 'La travesura de la bestia', 'Omar Fernandes', 3, 0),
#  ('Umar Uchoa', 'El bosque encantado de el lamento', 'Khaled Pereira', 2, 0),
#  ('Umar Uchoa', 'El guardián de la clave', 'Lakshmi Jimenez', 2, 0),
#  ('Umar Uchoa', 'La leyenda perdida de la tormenta', 'Yuri Teles', 1, 0),
#  ('Oscar Yilmaz', 'La batalla de la leyenda', 'Rosa Nguyen', 2, 0),
#  ('Han Almeida', 'El amanecer de la pesadilla', 'Elena Almeida', 3, 0),
#  ('Orhan Kumar', 'El hechizo de la salvación', 'Kamala Vargas', 2, 0),
#  ('Orhan Kumar', 'La metamorfosis de el monstruo', 'Nina Velez', 4, 1),
#  ('Orhan Kumar', 'El caballero de el adiós', 'Darya Gomes', 2, 0),
#  ('Umberto Yan', 'El guardián de el descubrimiento', 'Beatriz Cruz', 2, 0),
#  ('Umberto Yan', 'El laberinto de el león', 'Fabiana Cruz', 4, 1),
#  ('Umberto Yan', 'El laberinto de la esperanza', 'Gustavo Zhang', 2, 0),
#  ('Umberto Yan', 'La metamorfosis de la oscuridad', 'Leticia Yamamoto', 3, 0),
#  ('Chen Esteves', 'El caballero de la soledad', 'Hiroko Ferreira', 3, 0),
#  ('Chen Esteves', 'El laberinto de la esperanza', 'Vivek Ortega', 4, 0),
#  ('Chen Esteves', 'La travesía de el sol', 'Umar Mendes', 1, 0),
#  ('Chen Esteves', 'El tesoro escondido de el guerrero', 'Beatriz Diniz', 1, 0),
#  ('Chen Esteves', 'La maldición del vampiro de el león', 'Leticia Yamamoto', 3, 0),
#  ('Chen Esteves', 'La estrella fugaz de la ola', 'Leticia Fernandes', 4, 0),
#  ('Javier Janssen', 'La metamorfosis de el monstruo', 'Nina Velez', 4, 1),
#  ('Javier Janssen', 'El amanecer de el misterio', 'Fabiana Ueno', 1, 0),
#  ('Javier Janssen', 'El despertar de la sirena', 'Elena Almeida', 3, 0),
#  ('Javier Janssen', 'La trampa de la pesadilla', 'Pilar Uchoa', 2, 1),
#  ('Fadhila Estevez', 'La danza macabra de el lobo', 'Pilar Hidalgo', 1, 0),
#  ('Fadhila Estevez', 'La estrella fugaz de el ángel', 'Valentina Martinez', 2, 0),
#  ('Fadhila Estevez', 'La travesía sin retorno de el rincón', 'Zara Estevez', 3, 0),
#  ('Zara Oliveira', 'El renacimiento de el hechizo', 'Hiroko Sousa', 2, 1),
#  ('Zara Oliveira', 'El príncipe de la pesadilla', 'Elif Tan', 3, 0),
#  ('Zara Oliveira', 'El secreto de la montaña', 'Javier Henriquez', 4, 0),
#  ('Zara Oliveira', 'La búsqueda de el fuego', 'Elena Iglesias', 5, 2),
#  ('Zara Oliveira', 'La cripta de el valle', 'Parvati Olivares', 3, 0),
#  ('Fabiana Ortega', 'El destino de la sirena', 'Yasmin Queiroz', 2, 0),
#  ('Rashid Iglesias', 'El amanecer de el misterio', 'Fabiana Ueno', 1, 0),
#  ('Rashid Iglesias', 'El guardián de el horizonte', 'Vivek Ortega', 4, 0),
#  ('Rashid Iglesias', 'La leyenda perdida de la trampa', 'Yuri Janssen', 2, 0),
#  ('Rashid Iglesias', 'La leyenda perdida de la heroína', 'Pilar Uchoa', 2, 1),
#  ('Rashid Iglesias', 'El hechizo de la aventura', 'Fatemeh Gomes', 2, 0),
#  ('Leticia Watanabe', 'La búsqueda de el misterio', 'Orhan Goncalves', 2, 0),
#  ('Khaled Ortega', 'La invasión de la bruma', 'Sakura Lima', 2, 0),
#  ('Isa Xu', 'La invasión de la bruma', 'Sakura Lima', 2, 0),
#  ('Isa Xu', 'El hechizo de la misión', 'Qiu Pacheco', 3, 0),
#  ('Isa Xu', 'El refugio de la estrella fugaz', 'Rashid Janssen', 2, 0),
#  ('Tatjana Vargas', 'El despertar de la magia', 'Wan Nunes', 3, 0),
#  ('Orhan Velez', 'La búsqueda del tesoro de el pacto', 'Kamala Teixeira', 3, 0),
#  ('Orhan Velez', 'El laberinto de la esperanza', 'Gustavo Zhang', 2, 0),
#  ('Orhan Velez', 'La travesura de el faro', 'Giovanni Barros', 3, 0),
#  ('Kamala Oliveira', 'El resurgimiento de la venganza', 'Samir Xavier', 2, 1),
#  ('Kamala Oliveira', 'La escalada de el mar', 'Zoya Martinez', 5, 1),
#  ('Kamala Oliveira', 'La búsqueda del tesoro de el pacto', 'Kamala Teixeira', 3, 0),
#  ('Kamala Oliveira', 'El refugio de la guerra', 'Beatriz Cruz', 2, 0),
#  ('Orhan Zhang', 'La llave de la oscuridad', 'Wan Nunes', 3, 0),
#  ('Orhan Zhang', 'La travesura de el amanecer', 'Ilya Duarte', 3, 1),
#  ('Khaled Diniz', 'La venganza de la estrella fugaz', 'Dmitri Velez', 1, 0),
#  ('Natalia Rocha', 'La travesía del océano de la pesadilla', 'Wilhelmina Lima', 2, 0),
#  ('Natalia Rocha', 'El viajero de la maraña', 'Kamala Yan', 3, 0),
#  ('Natalia Rocha', 'La senda de la desgracia', 'Tatjana Urbina', 2, 0),
#  ('Natalia Rocha', 'La travesía sin retorno de la estrella', 'Lakshmi Jimenez', 2, 0),
#  ('Jasmin Dutta', 'El refugio de el río', 'Fadhila Yilmaz', 2, 0),
#  ('Oscar Bianchi', 'El regreso de la noche', 'Elena Iglesias', 5, 2),
#  ('Oscar Bianchi', 'La canción de el volcán', 'Darya Gomes', 2, 0),
#  ('Xavier Xu', 'La resurrección de la escuela', 'Darya Uchoa', 2, 0),
#  ('Xavier Xu', 'El príncipe de el amor', 'Zoya Vargas', 1, 0),
#  ('Xavier Xu', 'El caballero de la despedida', 'Kamala Yan', 3, 0),
#  ('Ursula Uchoa', 'La leyenda perdida de el laberinto', 'Tatjana Pereira', 3, 0),
#  ('Ursula Uchoa', 'El canto de sirena de la compañía', 'Yuri Janssen', 2, 0),
#  ('Ursula Uchoa', 'La rebelión de la corrupción', 'Chen Inácio', 2, 0),
#  ('Ursula Uchoa', 'El pacto de la aldea', 'Rosa Xavier', 1, 0),
#  ('Ursula Uchoa', 'El arco iris de el hechizo', 'Rosa Nguyen', 2, 0),
#  ('Ursula Uchoa', 'El viajero de el laberinto', 'Tatjana Pereira', 3, 0),
#  ('Mina Santana', 'La fuente de la perdición', 'Giovanni Zhang', 2, 0),
#  ('Mina Santana', 'La canción de el lamento', 'Zoya Nguyen', 4, 0),
#  ('Darius Ivanov', 'La batalla de el vuelo', 'Omar Lopes', 1, 1),
#  ('Darius Ivanov', 'El grito de el mar', 'Fabiana Cruz', 4, 1),
#  ('Zara Zambrano', 'La escalada de el mar', 'Zoya Martinez', 5, 1),
#  ('Zara Zambrano', 'La batalla de la montaña', 'Leticia Fernandes', 4, 0),
#  ('Zara Zambrano', 'La maldición del vampiro de el abismo', 'Nina Velez', 4, 1),
#  ('Valeria Qian', 'La búsqueda de el fuego', 'Elena Iglesias', 5, 2),
#  ('Valeria Qian', 'El canto de sirena de el faro', 'Zara Estevez', 3, 0),
#  ('Leticia Rodriguez', 'La leyenda perdida de el laberinto', 'Tatjana Pereira', 3, 0),
#  ('Leticia Rodriguez', 'El laberinto de la ola', 'Elif Urbina', 5, 0),
#  ('Irina Tan', 'El amanecer de la cárcel', 'Zara Estevez', 3, 0),
#  ('Irina Tan', 'La trampa de el guardián', 'Oscar Wu', 2, 0),
#  ('Irina Tan', 'La conquista de el camino', 'Leticia Diniz', 4, 0),
#  ('Javier Nguyen', 'La travesura de el amanecer', 'Ilya Duarte', 3, 1),
#  ('Javier Nguyen', 'El viaje de la resistencia', 'Ilya Duarte', 3, 1),
#  ('Patricia Borges', 'La conquista de la noche', 'Ximena Sousa', 1, 0),
#  ('Patricia Borges', 'La redención de la mariposa', 'Tatjana Pereira', 3, 0),
#  ('Patricia Borges', 'La danza de la pasión', 'Omar Nguyen', 4, 0),
#  ('Patricia Borges', 'La estirpe de la gárgola', 'Hiroko Sousa', 2, 1),
#  ('Rashid Lopes', 'La historia de el explorador', 'Beatriz Xavier', 1, 0),
#  ('Leticia Martinez', 'La redención de la caza', 'Qiu Wu', 3, 0),
#  ('Wilhelmina Kumar', 'El pacto de el tesoro', 'Giovanni Zhang', 2, 0),
#  ('Wilhelmina Kumar', 'El laberinto de la caza', 'Sakura Almeida', 3, 0),
#  ('Irina Xu', 'La travesura de la flor', 'Valentina Martinez', 2, 0),
#  ('Mina Rodriguez', 'La travesía sin retorno de la estrella', 'Lakshmi Jimenez', 2, 0),
#  ('Yuri Rodriguez', 'La invasión de la paz', 'Samir Xavier', 2, 1),
#  ('Rosa Lima', 'El descubrimiento de el puente', 'Umberto Olivares', 2, 0),
#  ('Rosa Lima', 'La estrella fugaz de el viaje', 'Fadhila Quintana', 1, 0),
#  ('Elif Wu', 'La escalada de el mar', 'Zoya Martinez', 5, 1),
#  ('Elif Wu', 'La fuga de la cascada', 'Beatriz Xia', 3, 0),
#  ('Elif Wu', 'El refugio de la estrella fugaz', 'Rashid Janssen', 2, 0),
#  ('Han Nguyen', 'El hechizo de el destino', 'Fadhila Xavier', 1, 0),
#  ('Han Nguyen', 'La leyenda de la corrupción', 'Qiu Pacheco', 3, 0),
#  ('Han Nguyen', 'La travesura de el secreto', 'Pilar Wu', 1, 1),
#  ('Han Nguyen', 'El eclipse de la batalla', 'Elif Urbina', 5, 0),
#  ('Tatiana Barros', 'El caballero de el adiós', 'Darya Gomes', 2, 0),
#  ('Tatiana Barros', 'La estirpe de la gárgola', 'Hiroko Sousa', 2, 1),
#  ('Mehmet Watanabe', 'El castillo de la heroína', 'Bianca Zambrano', 3, 1),
#  ('Mehmet Watanabe', 'El canto de sirena de la esperanza', 'Oscar Barros', 1, 0),
#  ('Mehmet Watanabe', 'El caballero de la despedida', 'Kamala Yan', 3, 0),
#  ('Mehmet Watanabe', 'La maldición de la cascada', 'Xin Ferreira', 1, 0),
#  ('Oscar Quintana', 'El despertar de la sirena', 'Elena Almeida', 3, 0),
#  ('Oscar Quintana', 'La travesía del océano de la esperanza', 'Mikhail Uchoa', 4, 1),
#  ('Xin Fernandes', 'La leyenda perdida de la tormenta', 'Yuri Teles', 1, 0),
#  ('Xin Fernandes', 'La batalla de el sueño', 'Zara Fernandes', 1, 0),
#  ('Xin Fernandes', 'El renacimiento de el lamento', 'Bianca Zambrano', 3, 1),
#  ('Han Nunes', 'La tormenta de la senda', 'Ilya Nguyen', 2, 0),
#  ('Zafar Ortega', 'La travesura de el faro', 'Giovanni Barros', 3, 0),
#  ('Zafar Ortega', 'El castillo de la heroína', 'Bianca Zambrano', 3, 1),
#  ('Fabiana Yilmaz', 'La metamorfosis de la bestia', 'Wilhelmina Lima', 2, 0),
#  ('Fabiana Yilmaz', 'La danza de la noche', 'Vivek Ortega', 4, 0),
#  ('Fabiana Yilmaz', 'El renacimiento de el hechizo', 'Hiroko Sousa', 2, 1),
#  ('Aarav Jimenez', 'La batalla de la montaña', 'Leticia Fernandes', 4, 0),
#  ('Aarav Jimenez', 'El hechizo de el laberinto', 'Zafar Xavier', 1, 0),
#  ('Tatjana Lopes', 'El refugio de la guerra', 'Rashid Queiroz', 1, 0),
#  ('Bianca Yilmaz', 'La maldición del vampiro de la muralla', 'Gustavo Zhang', 2, 0),
#  ('Bianca Yilmaz', 'La leyenda perdida de la tormenta', 'Yuri Teles', 1, 0),
#  ('Bianca Yilmaz', 'El amanecer de el árbol', 'Khaled Pereira', 2, 0),
#  ('Fabiana Diniz', 'El arco iris de la gárgola', 'Oscar Wu', 2, 0),
#  ('Fabiana Diniz', 'La cripta de la bailarina', 'Akira Barros', 1, 0),
#  ('Mehmet Lopez', 'La leyenda perdida de el laberinto', 'Tatjana Pereira', 3, 0),
#  ('Mehmet Lopez', 'El castillo de la heroína', 'Theresa Velez', 2, 1),
#  ('Mehmet Lopez', 'La venganza de la esperanza', 'Tatjana Urbina', 2, 0),
#  ('Mehmet Lopez', 'La invasión de el fuego', 'Fadhila Yilmaz', 2, 0),
#  ('Wilhelmina Pereira', 'La venganza de la bienvenida', 'Pilar Urbina', 3, 0),
#  ('Wilhelmina Pereira', 'El misterio de el hechicero', 'Umar Mendes', 5, 1),
#  ('Wilhelmina Pereira', 'La travesía sin retorno de el viaje', 'Wang Watanabe', 1, 0),
#  ('Alessandro Fernandes', 'El despertar de la sirena', 'Elena Almeida', 3, 0),
#  ('Alessandro Fernandes', 'La búsqueda del tesoro de la batalla', 'Gustavo Esteves', 1, 0),
#  ('Xavier Sousa', 'El prisionero de la venganza', 'Leticia Santana', 1, 0),
#  ('Xavier Sousa', 'El lamento de la aldea', 'Hanako Teixeira', 1, 0),
#  ('Xavier Sousa', 'El amanecer de el héroe', 'Fabiana Xu', 2, 1),
#  ('Jin Hernandez', 'La resurrección de el guardián', 'Han Ueno', 3, 1),
#  ('Jin Hernandez', 'El arco iris de la gárgola', 'Oscar Wu', 2, 0),
#  ('Umar Hidalgo', 'El caballero de la soledad', 'Hiroko Ferreira', 3, 0),
#  ('Umar Hidalgo', 'La maldición del vampiro de el abismo', 'Nina Velez', 4, 1),
#  ('Umar Hidalgo', 'La resurrección de el guardián', 'Han Ueno', 3, 1),
#  ('Umar Hidalgo', 'La batalla de la montaña', 'Leticia Fernandes', 4, 0),
#  ('Umar Hidalgo', 'La tormenta de el dragón', 'Chen Inácio', 2, 0),
#  ('Quintus Vargas', 'La invasión de la bruma', 'Sakura Lima', 2, 0),
#  ('Nina Kumar', 'El pacto de la aldea', 'Rosa Xavier', 1, 0),
#  ('Nina Kumar', 'La historia de el explorador', 'Beatriz Xavier', 1, 0),
#  ('Nina Kumar', 'La fortuna de el destino', 'Khaled Zambrano', 1, 0),
#  ('Hanako Ferreira', 'La fuente de el puente', 'Kamala Teixeira', 3, 0),
#  ('Hanako Ferreira', 'El tesoro de la fortuna', 'Tatiana Qian', 2, 0),
#  ('Hanako Ferreira', 'El caballero de el adiós', 'Darya Gomes', 2, 0),
#  ('Hanako Ferreira', 'El castillo de la heroína', 'Bianca Zambrano', 3, 1),
#  ('Qiu Velez', 'La trampa de la pesadilla', 'Pilar Uchoa', 2, 1),
#  ('Qiu Velez', 'La resurrección de la sombra', 'Giovanni Barros', 3, 0),
#  ('Elif Yilmaz', 'El tesoro de el castillo', 'Darius Alvarez', 1, 0),
#  ('Elif Yilmaz', 'La danza de la tormenta', 'Wan Esteves', 2, 0),
#  ('Elif Yilmaz', 'La búsqueda del tesoro de la tierra', 'Genghis Diniz', 1, 0),
#  ('Isa Watanabe', 'La travesía del océano de el abismo', 'Ilya Correia', 1, 0),
#  ('Isa Watanabe', 'El lamento de el monstruo', 'Quentin Zambrano', 1, 0),
#  ('Isa Watanabe', 'El regreso de la magia', 'Fabiana Cruz', 4, 1),
#  ('Isa Watanabe', 'La invasión de el enigma', 'Hiroko Sousa', 2, 1),
#  ('Dmitri Petrov', 'El vuelo de el explorador', 'Qiu Wu', 3, 0),
#  ('Dmitri Petrov', 'La batalla de la montaña', 'Leticia Fernandes', 4, 0),
#  ('Dmitri Petrov', 'El bosque encantado de la leyenda', 'Valeria Petrov', 2, 0),
#  ('Umberto Petrov', 'La travesura de el secreto', 'Pilar Wu', 1, 1),
#  ('Umberto Petrov', 'El arco iris de la tormenta', 'Genghis Oliveira', 1, 0),
#  ('Umberto Petrov', 'La venganza de la cascada', 'Fabiana Tan', 2, 0),
#  ('Hiroko Yan', 'El renacimiento de el grito', 'Lakshmi Lima', 2, 0),
#  ('Aarav Esteves', 'La escalada de el volcán', 'Gustavo Hernandez', 1, 0),
#  ('Pilar Jimenez', 'El resurgimiento de el destino', 'Natalia Barros', 1, 0),
#  ('Pilar Jimenez', 'La escalada de el enigma', 'Zara Hidalgo', 1, 0),
#  ('Valentina Ferreira', 'El eclipse de la pesadilla', 'Pilar Urbina', 3, 0),
#  ('Valentina Ferreira', 'La trampa de la estrella', 'Umar Mendes', 5, 1),
#  ('Valentina Ferreira', 'La conquista de la noche', 'Ximena Sousa', 1, 0),
#  ('Valentina Ferreira', 'El resurgimiento de el río', 'Beatriz Xia', 3, 0),
#  ('Valentina Ferreira', 'El espejismo de la princesa', 'Genghis Sousa', 2, 0),
#  ('Valentina Ferreira', 'El renacimiento de el hechizo', 'Hiroko Sousa', 2, 1),
#  ('Quintus Uchoa', 'La venganza de la estrella fugaz', 'Dmitri Velez', 1, 0),
#  ('Quintus Uchoa', 'La búsqueda de el fuego', 'Elena Iglesias', 5, 2),
#  ('Quintus Uchoa', 'La invasión de la espada mágica', 'Leticia Yamamoto', 3, 0),
#  ('Quintus Uchoa', 'El renacimiento de el lamento', 'Bianca Zambrano', 3, 1),
#  ('Sakura Queiroz', 'El renacimiento de la travesía', 'Parvati Ueno', 1, 0),
#  ('Yusef Watanabe', 'La estirpe de la gárgola', 'Hiroko Sousa', 2, 1),
#  ('Yusef Watanabe', 'La llegada de la criatura', 'Omar Uchoa', 2, 0),
#  ('Yusef Watanabe', 'La trampa de la criatura', 'Omar Uchoa', 2, 0),
#  ('Fabiana Vieira', 'El amanecer de el árbol', 'Khaled Pereira', 2, 0),
#  ('Fabiana Vieira', 'La venganza de la esperanza', 'Tatjana Urbina', 2, 0),
#  ('Fabiana Vieira', 'El regreso de la soledad', 'Pilar Urbina', 3, 0),
#  ('Fabiana Vieira', 'La leyenda perdida de la salvación', 'Jasmin Iglesias', 2, 0),
#  ('Fabiana Teixeira', 'El viajero de la maraña', 'Kamala Yan', 3, 0),
#  ('Jin Tan', 'El regreso de la caverna', 'Dmitri Nguyen', 3, 0),
#  ('Jin Tan', 'El misterio de el hechicero', 'Umar Mendes', 5, 1),
#  ('Wilhelmina Ivanov', 'La llave de el sueño', 'Ilya Duarte', 2, 1),
#  ('Wilhelmina Ivanov', 'El canto de sirena de la compañía', 'Yuri Janssen', 2, 0),
#  ('Javier Quintana', 'El eclipse de la travesía', 'Elif Tan', 3, 0),
#  ('Javier Quintana', 'La leyenda de la pesadilla', 'Wan Esteves', 2, 0),
#  ('Javier Quintana', 'La misión de el sol', 'Hiroko Goncalves', 3, 0),
#  ('Javier Quintana', 'El caballero de la despedida', 'Kamala Yan', 3, 0),
#  ('Javier Quintana', 'El pacto de la cripta', 'Hiroko Goncalves', 3, 0),
#  ('Javier Quintana', 'El eclipse de la puerta', 'Jasmin Cruz', 1, 0),
#  ('Valeria Almeida', 'La tormenta de el dragón', 'Chen Inácio', 2, 0),
#  ('Valeria Almeida', 'El tesoro escondido de el guerrero', 'Beatriz Diniz', 1, 0),
#  ('Valeria Gao', 'La travesura de el secreto', 'Pilar Wu', 1, 1),
#  ('Valeria Gao', 'La tormenta de el dragón', 'Chen Inácio', 2, 0),
#  ('Quentin Quintana', 'El ritual de la fortuna', 'Beatriz Teixeira', 2, 1),
#  ('Quentin Quintana', 'La trampa de la criatura', 'Omar Uchoa', 2, 0),
#  ('Quentin Quintana', 'El bosque encantado de la leyenda', 'Valeria Petrov', 2, 0),
#  ('Quentin Quintana', 'El renacimiento de el legado', 'Parvati Olivares', 3, 0),
#  ('Chidike Lopez', 'La danza de la tormenta', 'Wan Esteves', 2, 0),
#  ('Chidike Lopez', 'El bosque encantado de la leyenda', 'Valeria Petrov', 2, 0),
#  ('Chidike Lopez', 'El tesoro escondido de la fortuna', 'Zoya Martinez', 5, 1),
#  ('Bianca Esteves', 'El amanecer de la bailarina', 'Zoya Nguyen', 4, 0),
#  ('Bianca Esteves', 'La travesura de la cueva', 'Elif Tan', 3, 0),
#  ('Bianca Esteves', 'La escalada de el mar', 'Zoya Martinez', 5, 1),
#  ('Yusef Yamamoto', 'La trampa de el guardián', 'Oscar Wu', 2, 0),
#  ('Yusef Yamamoto', 'El refugio de la guerra', 'Rashid Queiroz', 1, 0),
#  ('Salim Kawaguchi', 'La tormenta de la senda', 'Ilya Nguyen', 2, 0),
#  ('Salim Kawaguchi', 'La travesía del océano de la estrella', 'Orhan Goncalves', 2, 0),
#  ('Salim Kawaguchi', 'El laberinto de la ola', 'Elif Urbina', 5, 0),
#  ('Yuri Estevez', 'El espejismo de la cascada', 'Hiroko Goncalves', 3, 0),
#  ('Yuri Estevez', 'La travesía sin retorno de la escuela', 'Irina Sousa', 3, 2),
#  ('Yuri Estevez', 'El misterio de el desafío', 'Chidike Zhang', 2, 1),
#  ('Yuri Estevez', 'El descubrimiento de la princesa', 'Parvati Mendes', 1, 0),
#  ('Yuri Estevez', 'El hechizo de la aventura', 'Fatemeh Gomes', 2, 0),
#  ('Giovanni Rodriguez', 'La danza de la noche', 'Vivek Ortega', 4, 0),
#  ('Giovanni Rodriguez', 'El cuento de hadas de la isla', 'Jasmin Santos', 2, 1),
#  ('Giovanni Rodriguez', 'El tesoro escondido de el valle', 'Javier Alvarez', 3, 1),
#  ('Giovanni Rodriguez', 'El regreso de la magia', 'Fabiana Cruz', 4, 1),
#  ('Fabiana Santos', 'El bosque encantado de la promesa', 'Natalia Velez', 1, 0),
#  ('Fabiana Santos', 'El bosque encantado de el lamento', 'Khaled Pereira', 2, 0),
#  ('Emiko Carvalho', 'La búsqueda de el renacimiento', 'Yuri Ortega', 1, 1),
#  ('Emiko Carvalho', 'El vuelo mágico de la selva', 'Khaled Urbina', 1, 0),
#  ('Samir Zapata', 'La odisea de la reina', 'Quentin Quintana', 1, 0),
#  ('Samir Zapata', 'El tesoro escondido de la ley', 'Mina Yan', 2, 0),
#  ('Samir Yamamoto', 'La travesura de la bestia', 'Omar Fernandes', 3, 0),
#  ('Samir Yamamoto', 'La travesía de el sol', 'Umar Mendes', 1, 0),
#  ('Dmitri Olivares', 'El viajero de el laberinto', 'Tatjana Pereira', 3, 0),
#  ('Jasmin Inácio', 'El camino hacia el adiós', 'Omar Fernandes', 3, 0),
#  ('Jasmin Inácio', 'El refugio de la guerra', 'Beatriz Cruz', 2, 0),
#  ('Qiu Gomes', 'La conquista de la noche', 'Ximena Sousa', 1, 0),
#  ('Qiu Gomes', 'La maldición del vampiro de la muralla', 'Gustavo Zhang', 2, 0),
#  ('Javier Ueno', 'El canto de sirena de el faro', 'Zara Estevez', 3, 0),
#  ('Javier Ueno', 'El regreso de la caverna', 'Dmitri Nguyen', 3, 0)]

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=cafe4e99-499e-4e36-b9fd-48e2d31e0196' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
